# %% [markdown]
# ## Setup

# %%
# Facial image emotion recognition using CNN
# Target classes: Angry, Disgusted, Fearful, Happy, Sad, Surprised, Neutral

import tensorflow as tf

NUM_THREADS = 32

tf.config.threading.set_intra_op_parallelism_threads(NUM_THREADS)
tf.config.threading.set_inter_op_parallelism_threads(NUM_THREADS)

# Switch to GPU
physical_devices = tf.config.experimental.list_physical_devices("GPU")
print("Num GPUs Available: ", len(physical_devices))
print(physical_devices)
for dev in physical_devices:
    tf.config.experimental.set_memory_growth(dev, True)


# DATASET
# files in dataset/test and dataset/train
# subfolders: angry, disgusted, fearful, happy, sad, surprised, neutral

# load dataset
train_dir = "dataset/train"
test_dir = "dataset/test"
# Out:
# 2024-07-11 10:05:37.847253: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-11 10:05:37.870384: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-11 10:05:37.870418: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-11 10:05:37.886408: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-11 10:05:38.617800: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Num GPUs Available:  2
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
# Test data
# Check for the number of images in each class and the size of the images
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "0"  # 0 = alle Meldungen werden ausgegeben

# List of classes
classes = sorted(["angry", "disgust", "fear", "happy", "sad", "surprise", "neutral"])

# Number of images in each class
print("Number of training images in each class:")
for c in classes:
    path = os.path.join(train_dir, c)
    print(f"{c}: {len(os.listdir(path))} images")

print("\nNumber of test images in each class:")
for c in classes:
    path = os.path.join(test_dir, c)
    print(f"{c}: {len(os.listdir(path))} images")

# Image size
img = cv2.imread("dataset/train/angry/Training_3908.jpg")
print(f"\nImage size: {img.shape}")

input_shape = img.shape

# Reduce image size to 48x48 pixels due to greyscale (original size: 48x48x3)
input_shape = (48, 48, 1)
# Out:
# Number of training images in each class:
# angry: 4162 images
# disgust: 411 images
# fear: 4171 images
# happy: 7628 images
# sad: 5073 images
# surprise: 2842 images
# neutral: 5248 images
#
# Number of test images in each class:
# angry: 939 images
# disgust: 84 images
# fear: 982 images
# happy: 1850 images
# sad: 1270 images
# surprise: 610 images
# neutral: 1255 images
#
# Image size: (48, 48, 3)

# %% [markdown]
# ## Loading the images from disk

# %%
import dataloader

greyscale = True
augmentation = None

train_ds, test_ds = dataloader.load(
    train_dir, test_dir, 7, OneChannelOnly=greyscale, augmentations=augmentation
)
# Out:
# Found 29535 files belonging to 7 classes.
# 2024-07-11 10:05:42.084418: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 660 MB memory:  -> device: 0, name: Quadro RTX 6000, pci bus id: 0000:17:00.0, compute capability: 7.5
# 2024-07-11 10:05:42.084925: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22769 MB memory:  -> device: 1, name: Quadro RTX 6000, pci bus id: 0000:65:00.0, compute capability: 7.5
# Found 6990 files belonging to 7 classes.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Show the first 16 images and their labels
for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    for i in range(16):
        ax = plt.subplot(4, 4, i + 1)
        if greyscale:
            plt.imshow(np.squeeze(images[i]), cmap="gray")
        else:
            plt.imshow(images[i])
        plt.title(np.argmax(labels[i]))
        plt.axis("off")
    plt.show()
# Out:
# 2024-07-11 10:05:44.389078: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Print one image (to confirm whether the images are represented as 48x48x1 tensors)
for img, label in train_ds.take(1):
    print(f"Image shape: {img.shape}, Label dtype: {label.dtype}")
    print(f"Image dtype: {img.dtype}, Label dtype: {label.dtype}")

    # Plot the image
    if greyscale:
        plt.imshow(np.squeeze(img[0]), cmap="gray")
    else:
        plt.imshow(img[0])
    plt.show()
# Out:
# Image shape: (64, 48, 48, 1), Label dtype: <dtype: 'float32'>
# Image dtype: <dtype: 'float32'>, Label dtype: <dtype: 'float32'>
# 2024-07-11 10:05:44.485047: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ## Class distribution and weights

# %%
import collections


def get_class_distribution(dataset):
    class_counts = collections.Counter()

    for _, label_batch in dataset:
        labels = tf.argmax(label_batch, axis=1)
        class_counts.update(labels.numpy())

    return class_counts


# Klassenverteilung im Trainingsdatensatz
train_class_distribution = get_class_distribution(train_ds)
print("Train Class Distribution:", train_class_distribution)

# Klassenverteilung im Testdatensatz
test_class_distribution = get_class_distribution(test_ds)
print("Test Class Distribution:", test_class_distribution)


def plot_class_distributions(train_distribution, test_distribution, class_labels):
    classes = sorted(
        set(train_distribution.keys()).union(set(test_distribution.keys()))
    )

    train_counts = [train_distribution[cls] for cls in classes]
    test_counts = [test_distribution[cls] for cls in classes]

    width = 0.4  # width of the bars
    x = range(len(classes))  # the label locations

    fig, ax = plt.subplots()

    ax.bar(x, train_counts, width, label="Train", align="center")
    ax.bar([p + width for p in x], test_counts, width, label="Test", align="center")

    ax.set_xlabel("Class / Label Index")
    ax.set_ylabel("Count / %")
    ax.set_title("Class Distribution in Train and Test Datasets")
    ax.set_xticks([p + width / 2 for p in x])
    ax.set_xticklabels([class_labels[cls] for cls in classes])
    ax.legend()

    plt.show()


class_labels = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

train_total = sum(train_class_distribution.values())
test_total = sum(test_class_distribution.values())

train_class_distribution = {
    k: v / train_total for k, v in train_class_distribution.items()
}
test_class_distribution = {
    k: v / test_total for k, v in test_class_distribution.items()
}

plot_class_distributions(train_class_distribution, test_class_distribution, class_labels)
# Out:
# 2024-07-11 10:05:44.633231: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Train Class Distribution: Counter({3: 1850, 5: 1270, 4: 1255, 2: 982, 0: 939, 6: 610, 1: 84})
# Test Class Distribution: Counter({3: 7628, 4: 5248, 5: 5073, 2: 4171, 0: 4162, 6: 2842, 1: 411})
# 2024-07-11 10:05:44.979913: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
import sklearn
from sklearn.utils import class_weight

# Load labels as vector
y_train = []
for i, c in enumerate(classes):
    path = os.path.join(train_dir, c)
    for img_name in os.listdir(path):
        if img is not None:  # Ensure the image was read correctly
            y_train.append(i)

# %%
y_train_encoded = tf.keras.utils.to_categorical(y_train, num_classes=7)

# Nehme an, y_train_labels sind die Labels deiner Trainingsdaten
y_train_labels = np.argmax(y_train_encoded, axis=1)
y_train_labels = y_train_labels.astype(np.int32)

# Berechnung der Klassengewichte
class_weights = class_weight.compute_class_weight(
    class_weight="balanced", classes=np.unique(y_train_labels), y=y_train_labels
)

# Convert the class weights to a dictionary. Use np.int32 as the key type
class_weights_dict = {
    int(k): float(v) for k, v in zip(np.unique(y_train_labels), class_weights)
}

print("Class weights:", class_weights_dict)
# Print the type of keys in the dictionary
print("Type of keys:", type(list(class_weights_dict.keys())[0]))
# Print the type of values in the dictionary
print("Type of values:", type(list(class_weights_dict.values())[0]))
# Out:
# Class weights: {0: 1.0137639870941169, 1: 10.265901981230448, 2: 1.0115765318354626, 3: 0.5531313206981796, 4: 0.8317141167525556, 5: 1.4846184779330451, 6: 0.8039797473867596}
# Type of keys: <class 'int'>
# Type of values: <class 'float'>

# %%
# Callback functions
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_accuracy", patience=50, restore_best_weights=True, mode="max"
)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_accuracy", factor=0.5, patience=20, min_lr=0.00001, mode="max"
)

# %% [markdown]
# ## Preparing the model

# %%
import densenet
from tensorflow.keras import optimizers

input_shape = (48, 48, 1)
args = dict(
    input_shape = input_shape,
    num_blocks = 4,
    num_layers_per_block = [6, 12, 24, 16],  # DenseNet-121 configuration
    growth_rate = 32,
    reduction = 0.5,
    num_classes = 7,
    dropout_rate=0.3,      
    l2_regularization=1e-4,
)
model = densenet.DenseNet(**args)
model.build((None, *input_shape))
model.compile(
    optimizer=optimizers.Adam(),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
model(tf.keras.Input(input_shape))
model.summary()
# Out:
# /data/hagemann/ml/venv/lib/python3.12/site-packages/keras/src/layers/layer.py:372: UserWarning: `build()` was called on layer 'dense_net', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Model: "dense_net"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 24, 24, 64)     │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_block_1 (DenseBlock)      │ ?                      │       338,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transition_layer_1              │ ?                      │       133,120 │
# │ (TransitionLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_block_2 (DenseBlock)      │ ?                      │     1,132,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transition_layer_2              │ ?                      │       824,320 │
# │ (TransitionLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_block_3 (DenseBlock)      │ ?                      │     4,090,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ transition_layer_3              │ ?                      │     3,976,192 │
# │ (TransitionLayer)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_block_4 (DenseBlock)      │ ?                      │     4,078,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_117         │ (None, 1, 1, 3840)     │        15,360 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_117 (ReLU)                │ (None, 1, 1, 3840)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 3840)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 7)              │        26,887 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,619,335 (55.77 MB)
#  Trainable params: 14,474,247 (55.21 MB)
#  Non-trainable params: 145,088 (566.75 KB)

# %% [markdown]
# ## Training & Evaluation

# %%
history = model.fit(
    train_ds,
    class_weight=class_weights_dict,
    epochs=10,
    validation_data=test_ds,
    callbacks=[reduce_lr, early_stopping],
)
# Out:
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1720685182.544951   54317 service.cc:145] XLA service 0x7fc70c0365e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1720685182.545058   54317 service.cc:153]   StreamExecutor device (0): Quadro RTX 6000, Compute Capability 7.5
# I0000 00:00:1720685182.545072   54317 service.cc:153]   StreamExecutor device (1): Quadro RTX 6000, Compute Capability 7.5
# 2024-07-11 10:06:23.877453: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-11 10:06:28.103720: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
# 2024-07-11 10:06:32.563932: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 565.92MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-11 10:06:32.623411: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 547.89MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-11 10:06:32.683828: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 529.86MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-11 10:06:32.748530: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 511.83MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-11 10:06:32.808418: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 493.80MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-11 10:06:32.869499: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 475.77MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-11 10:06:32.931988: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 457.73MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-11 10:06:32.994471: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 439.70MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-11 10:06:33.188272: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 421.67MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-11 10:06:33.256020: W external/local_tsl/tsl/framework/bfc_allocator.cc:368] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2024-07-11 10:06:35.318502: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.78GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1720685219.445603   54317 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion_46', 136 bytes spill stores, 136 bytes spill loads
#
# I0000 00:00:1720685219.557492   54317 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-07-11 10:06:59.625892: W external/local_tsl/tsl/framework/bfc_allocator.cc:368] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2024-07-11 10:07:09.649765: W external/local_tsl/tsl/framework/bfc_allocator.cc:487] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.12MiB (rounded to 3276800)requested by op
# 2024-07-11 10:07:09.649861: I external/local_tsl/tsl/framework/bfc_allocator.cc:1044] BFCAllocator dump for GPU_0_bfc
# 2024-07-11 10:07:09.649896: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (256): 	Total Chunks: 169, Chunks in use: 169. 42.2KiB allocated for chunks. 42.2KiB in use in bin. 5.2KiB client-requested in use in bin.
# 2024-07-11 10:07:09.649926: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (512): 	Total Chunks: 340, Chunks in use: 340. 174.5KiB allocated for chunks. 174.5KiB in use in bin. 172.2KiB client-requested in use in bin.
# 2024-07-11 10:07:09.649954: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (1024): 	Total Chunks: 74, Chunks in use: 74. 102.0KiB allocated for chunks. 102.0KiB in use in bin. 97.3KiB client-requested in use in bin.
# 2024-07-11 10:07:09.649981: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (2048): 	Total Chunks: 108, Chunks in use: 108. 289.0KiB allocated for chunks. 289.0KiB in use in bin. 281.8KiB client-requested in use in bin.
# 2024-07-11 10:07:09.650007: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (4096): 	Total Chunks: 149, Chunks in use: 149. 845.0KiB allocated for chunks. 845.0KiB in use in bin. 830.2KiB client-requested in use in bin.
# 2024-07-11 10:07:09.650034: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (8192): 	Total Chunks: 20, Chunks in use: 20. 238.5KiB allocated for chunks. 238.5KiB in use in bin. 216.5KiB client-requested in use in bin.
# 2024-07-11 10:07:09.650059: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-11 10:07:09.650085: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (32768): 	Total Chunks: 8, Chunks in use: 8. 320.0KiB allocated for chunks. 320.0KiB in use in bin. 320.0KiB client-requested in use in bin.
# 2024-07-11 10:07:09.650109: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (65536): 	Total Chunks: 17, Chunks in use: 17. 1.52MiB allocated for chunks. 1.52MiB in use in bin. 1.48MiB client-requested in use in bin.
# 2024-07-11 10:07:09.650135: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (131072): 	Total Chunks: 122, Chunks in use: 122. 19.35MiB allocated for chunks. 19.35MiB in use in bin. 18.31MiB client-requested in use in bin.
# 2024-07-11 10:07:09.650161: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (262144): 	Total Chunks: 41, Chunks in use: 41. 14.05MiB allocated for chunks. 14.05MiB in use in bin. 12.72MiB client-requested in use in bin.
# 2024-07-11 10:07:09.650186: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (524288): 	Total Chunks: 68, Chunks in use: 68. 48.06MiB allocated for chunks. 48.06MiB in use in bin. 45.62MiB client-requested in use in bin.
# 2024-07-11 10:07:09.650210: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-11 10:07:09.650234: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (2097152): 	Total Chunks: 2, Chunks in use: 1. 5.39MiB allocated for chunks. 3.12MiB in use in bin. 3.12MiB client-requested in use in bin.
# 2024-07-11 10:07:09.650259: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (4194304): 	Total Chunks: 1, Chunks in use: 1. 5.41MiB allocated for chunks. 5.41MiB in use in bin. 3.12MiB client-requested in use in bin.
# 2024-07-11 10:07:09.650299: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (8388608): 	Total Chunks: 2, Chunks in use: 2. 30.25MiB allocated for chunks. 30.25MiB in use in bin. 30.25MiB client-requested in use in bin.
# 2024-07-11 10:07:09.650322: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-11 10:07:09.650343: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-11 10:07:09.650365: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-11 10:07:09.650386: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-11 10:07:09.650410: I external/local_tsl/tsl/framework/bfc_allocator.cc:1051] Bin (268435456): 	Total Chunks: 1, Chunks in use: 1. 534.44MiB allocated for chunks. 534.44MiB in use in bin. 498.41MiB client-requested in use in bin.
# 2024-07-11 10:07:09.650431: I external/local_tsl/tsl/framework/bfc_allocator.cc:1067] Bin for 3.12MiB was 2.00MiB, Chunk State:
# 2024-07-11 10:07:09.650460: I external/local_tsl/tsl/framework/bfc_allocator.cc:1073]   Size: 2.27MiB | Requested Size: 1B | in_use: 0 | bin_num: 13, prev:   Size: 5.0KiB | Requested Size: 5.0KiB | in_use: 1 | bin_num: -1
# 2024-07-11 10:07:09.650479: I external/local_tsl/tsl/framework/bfc_allocator.cc:1080] Next region of size 560398336
# 2024-07-11 10:07:09.650512: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc560000000 of size 560398336 next 18446744073709551615
# 2024-07-11 10:07:09.650530: I external/local_tsl/tsl/framework/bfc_allocator.cc:1080] Next region of size 67108864
# 2024-07-11 10:07:09.650548: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68c000000 of size 15859712 next 567
# 2024-07-11 10:07:09.650566: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68cf20000 of size 589824 next 815
# 2024-07-11 10:07:09.650583: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68cfb0000 of size 606208 next 817
# 2024-07-11 10:07:09.650601: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68d044000 of size 622592 next 820
# 2024-07-11 10:07:09.650619: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68d0dc000 of size 638976 next 822
# 2024-07-11 10:07:09.650637: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68d178000 of size 655360 next 824
# 2024-07-11 10:07:09.650654: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68d218000 of size 671744 next 826
# 2024-07-11 10:07:09.650671: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68d2bc000 of size 688128 next 828
# 2024-07-11 10:07:09.650688: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68d364000 of size 704512 next 830
# 2024-07-11 10:07:09.650706: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68d410000 of size 15859712 next 832
# 2024-07-11 10:07:09.650723: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68e330000 of size 720896 next 834
# 2024-07-11 10:07:09.650740: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68e3e0000 of size 737280 next 836
# 2024-07-11 10:07:09.650758: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68e494000 of size 753664 next 838
# 2024-07-11 10:07:09.650775: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68e54c000 of size 770048 next 840
# 2024-07-11 10:07:09.650792: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68e608000 of size 786432 next 843
# 2024-07-11 10:07:09.650810: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68e6c8000 of size 802816 next 846
# 2024-07-11 10:07:09.650827: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68e78c000 of size 819200 next 848
# 2024-07-11 10:07:09.650844: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68e854000 of size 835584 next 850
# 2024-07-11 10:07:09.650861: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68e920000 of size 851968 next 852
# 2024-07-11 10:07:09.650878: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68e9f0000 of size 868352 next 854
# 2024-07-11 10:07:09.650896: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68eac4000 of size 884736 next 856
# 2024-07-11 10:07:09.650913: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68eb9c000 of size 901120 next 858
# 2024-07-11 10:07:09.650930: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68ec78000 of size 917504 next 860
# 2024-07-11 10:07:09.650947: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68ed58000 of size 933888 next 862
# 2024-07-11 10:07:09.650965: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68ee3c000 of size 950272 next 865
# 2024-07-11 10:07:09.650982: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68ef24000 of size 114688 next 866
# 2024-07-11 10:07:09.650999: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68ef40000 of size 966656 next 868
# 2024-07-11 10:07:09.651016: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f02c000 of size 107520 next 870
# 2024-07-11 10:07:09.651033: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f046400 of size 524288 next 874
# 2024-07-11 10:07:09.651051: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f0c6400 of size 131072 next 876
# 2024-07-11 10:07:09.651068: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f0e6400 of size 147456 next 879
# 2024-07-11 10:07:09.651085: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f10a400 of size 589824 next 883
# 2024-07-11 10:07:09.651103: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f19a400 of size 256 next 885
# 2024-07-11 10:07:09.651120: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f19a500 of size 256 next 893
# 2024-07-11 10:07:09.651137: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f19a600 of size 256 next 894
# 2024-07-11 10:07:09.651154: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f19a700 of size 256 next 895
# 2024-07-11 10:07:09.651171: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f19a800 of size 256 next 896
# 2024-07-11 10:07:09.651188: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f19a900 of size 256 next 897
# 2024-07-11 10:07:09.651205: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f19aa00 of size 256 next 898
# 2024-07-11 10:07:09.651222: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f19ab00 of size 256 next 899
# 2024-07-11 10:07:09.651239: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f19ac00 of size 32768 next 900
# 2024-07-11 10:07:09.651257: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f1a2c00 of size 32768 next 901
# 2024-07-11 10:07:09.651274: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f1aac00 of size 512 next 902
# 2024-07-11 10:07:09.651298: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f1aae00 of size 512 next 903
# 2024-07-11 10:07:09.651315: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f1ab000 of size 512 next 904
# 2024-07-11 10:07:09.651332: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f1ab200 of size 512 next 905
# 2024-07-11 10:07:09.651349: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f1ab400 of size 147456 next 906
# 2024-07-11 10:07:09.651366: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f1cf400 of size 147456 next 907
# 2024-07-11 10:07:09.651383: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f1f3400 of size 512 next 908
# 2024-07-11 10:07:09.651400: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f1f3600 of size 512 next 909
# 2024-07-11 10:07:09.651417: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f1f3800 of size 512 next 910
# 2024-07-11 10:07:09.651434: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f1f3a00 of size 512 next 911
# 2024-07-11 10:07:09.651451: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f1f3c00 of size 49152 next 912
# 2024-07-11 10:07:09.651469: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f1ffc00 of size 49152 next 913
# 2024-07-11 10:07:09.651486: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f20bc00 of size 512 next 914
# 2024-07-11 10:07:09.651503: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f20be00 of size 512 next 915
# 2024-07-11 10:07:09.651520: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f20c000 of size 512 next 916
# 2024-07-11 10:07:09.651537: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f20c200 of size 512 next 917
# 2024-07-11 10:07:09.651554: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f20c400 of size 147456 next 918
# 2024-07-11 10:07:09.651572: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f230400 of size 147456 next 919
# 2024-07-11 10:07:09.651589: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f254400 of size 512 next 920
# 2024-07-11 10:07:09.651605: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f254600 of size 512 next 921
# 2024-07-11 10:07:09.651622: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f254800 of size 512 next 922
# 2024-07-11 10:07:09.651639: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f254a00 of size 512 next 923
# 2024-07-11 10:07:09.651656: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f254c00 of size 65536 next 924
# 2024-07-11 10:07:09.651674: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f264c00 of size 65536 next 925
# 2024-07-11 10:07:09.651691: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f274c00 of size 512 next 926
# 2024-07-11 10:07:09.651708: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f274e00 of size 512 next 927
# 2024-07-11 10:07:09.651725: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f275000 of size 512 next 928
# 2024-07-11 10:07:09.651742: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f275200 of size 512 next 929
# 2024-07-11 10:07:09.651759: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f275400 of size 147456 next 930
# 2024-07-11 10:07:09.651776: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f299400 of size 147456 next 931
# 2024-07-11 10:07:09.651793: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f2bd400 of size 768 next 932
# 2024-07-11 10:07:09.651810: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f2bd700 of size 768 next 933
# 2024-07-11 10:07:09.651827: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f2bda00 of size 768 next 934
# 2024-07-11 10:07:09.651843: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f2bdd00 of size 768 next 935
# 2024-07-11 10:07:09.651861: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f2be000 of size 81920 next 936
# 2024-07-11 10:07:09.651879: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f2d2000 of size 81920 next 937
# 2024-07-11 10:07:09.651896: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f2e6000 of size 512 next 938
# 2024-07-11 10:07:09.651913: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f2e6200 of size 512 next 939
# 2024-07-11 10:07:09.651930: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f2e6400 of size 512 next 940
# 2024-07-11 10:07:09.651946: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f2e6600 of size 512 next 941
# 2024-07-11 10:07:09.651964: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f2e6800 of size 147456 next 942
# 2024-07-11 10:07:09.651981: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f30a800 of size 147456 next 943
# 2024-07-11 10:07:09.651998: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f32e800 of size 768 next 944
# 2024-07-11 10:07:09.652014: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f32eb00 of size 768 next 945
# 2024-07-11 10:07:09.652032: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f32ee00 of size 768 next 946
# 2024-07-11 10:07:09.652049: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f32f100 of size 768 next 947
# 2024-07-11 10:07:09.652066: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f32f400 of size 98304 next 948
# 2024-07-11 10:07:09.652083: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f347400 of size 98304 next 949
# 2024-07-11 10:07:09.652100: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f35f400 of size 512 next 950
# 2024-07-11 10:07:09.652118: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f35f600 of size 512 next 951
# 2024-07-11 10:07:09.652135: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f35f800 of size 512 next 952
# 2024-07-11 10:07:09.652151: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f35fa00 of size 512 next 953
# 2024-07-11 10:07:09.652169: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f35fc00 of size 147456 next 954
# 2024-07-11 10:07:09.652186: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f383c00 of size 147456 next 955
# 2024-07-11 10:07:09.652203: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f3a7c00 of size 1024 next 956
# 2024-07-11 10:07:09.652221: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f3a8000 of size 1024 next 957
# 2024-07-11 10:07:09.652238: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f3a8400 of size 1024 next 958
# 2024-07-11 10:07:09.652254: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f3a8800 of size 1024 next 959
# 2024-07-11 10:07:09.652271: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f3a8c00 of size 114688 next 960
# 2024-07-11 10:07:09.652293: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f3c4c00 of size 114688 next 961
# 2024-07-11 10:07:09.652310: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f3e0c00 of size 512 next 962
# 2024-07-11 10:07:09.652328: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f3e0e00 of size 512 next 963
# 2024-07-11 10:07:09.652345: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f3e1000 of size 512 next 964
# 2024-07-11 10:07:09.652361: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f3e1200 of size 512 next 965
# 2024-07-11 10:07:09.652378: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f3e1400 of size 147456 next 966
# 2024-07-11 10:07:09.652395: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f405400 of size 147456 next 967
# 2024-07-11 10:07:09.652413: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f429400 of size 2048 next 968
# 2024-07-11 10:07:09.652430: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f429c00 of size 2048 next 969
# 2024-07-11 10:07:09.652447: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f42a400 of size 2048 next 970
# 2024-07-11 10:07:09.652464: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f42ac00 of size 2048 next 971
# 2024-07-11 10:07:09.652481: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f42b400 of size 524288 next 972
# 2024-07-11 10:07:09.652498: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f4ab400 of size 524288 next 973
# 2024-07-11 10:07:09.652515: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f52b400 of size 1024 next 974
# 2024-07-11 10:07:09.652532: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f52b800 of size 1024 next 975
# 2024-07-11 10:07:09.652549: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f52bc00 of size 1024 next 976
# 2024-07-11 10:07:09.652566: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f52c000 of size 1024 next 977
# 2024-07-11 10:07:09.652583: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f52c400 of size 131072 next 978
# 2024-07-11 10:07:09.652601: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f54c400 of size 131072 next 979
# 2024-07-11 10:07:09.652618: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f56c400 of size 512 next 980
# 2024-07-11 10:07:09.652635: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f56c600 of size 512 next 981
# 2024-07-11 10:07:09.652653: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f56c800 of size 512 next 982
# 2024-07-11 10:07:09.652669: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f56ca00 of size 512 next 983
# 2024-07-11 10:07:09.652686: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f56cc00 of size 147456 next 984
# 2024-07-11 10:07:09.652703: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f590c00 of size 147456 next 985
# 2024-07-11 10:07:09.652721: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f5b4c00 of size 1280 next 986
# 2024-07-11 10:07:09.652738: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f5b5100 of size 1280 next 987
# 2024-07-11 10:07:09.652755: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f5b5600 of size 1280 next 988
# 2024-07-11 10:07:09.652772: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f5b5b00 of size 1280 next 989
# 2024-07-11 10:07:09.652789: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f5b6000 of size 147456 next 990
# 2024-07-11 10:07:09.652806: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f5da000 of size 147456 next 991
# 2024-07-11 10:07:09.652823: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f5fe000 of size 512 next 992
# 2024-07-11 10:07:09.652840: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f5fe200 of size 512 next 993
# 2024-07-11 10:07:09.652857: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f5fe400 of size 512 next 994
# 2024-07-11 10:07:09.652874: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f5fe600 of size 512 next 995
# 2024-07-11 10:07:09.652891: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f5fe800 of size 147456 next 996
# 2024-07-11 10:07:09.652908: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f622800 of size 147456 next 997
# 2024-07-11 10:07:09.652925: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f646800 of size 1280 next 998
# 2024-07-11 10:07:09.652942: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f646d00 of size 1280 next 999
# 2024-07-11 10:07:09.652959: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f647200 of size 1280 next 1000
# 2024-07-11 10:07:09.652976: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f647700 of size 1280 next 1001
# 2024-07-11 10:07:09.652993: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f647c00 of size 163840 next 1002
# 2024-07-11 10:07:09.653011: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f66fc00 of size 163840 next 1003
# 2024-07-11 10:07:09.653028: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f697c00 of size 512 next 1004
# 2024-07-11 10:07:09.653045: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f697e00 of size 512 next 1005
# 2024-07-11 10:07:09.653062: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f698000 of size 512 next 1006
# 2024-07-11 10:07:09.653079: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f698200 of size 512 next 1007
# 2024-07-11 10:07:09.653096: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f698400 of size 147456 next 1008
# 2024-07-11 10:07:09.653113: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f6bc400 of size 147456 next 1009
# 2024-07-11 10:07:09.653131: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f6e0400 of size 1536 next 1010
# 2024-07-11 10:07:09.653148: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f6e0a00 of size 1536 next 1011
# 2024-07-11 10:07:09.653166: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f6e1000 of size 1536 next 1012
# 2024-07-11 10:07:09.653183: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f6e1600 of size 1536 next 1013
# 2024-07-11 10:07:09.653200: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f6e1c00 of size 180224 next 1014
# 2024-07-11 10:07:09.653217: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f70dc00 of size 180224 next 1015
# 2024-07-11 10:07:09.653234: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f739c00 of size 512 next 1016
# 2024-07-11 10:07:09.653251: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f739e00 of size 512 next 1017
# 2024-07-11 10:07:09.653268: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f73a000 of size 512 next 1018
# 2024-07-11 10:07:09.653292: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f73a200 of size 512 next 1019
# 2024-07-11 10:07:09.653309: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f73a400 of size 147456 next 1020
# 2024-07-11 10:07:09.653326: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f75e400 of size 147456 next 1021
# 2024-07-11 10:07:09.653343: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f782400 of size 1536 next 1022
# 2024-07-11 10:07:09.653360: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f782a00 of size 1536 next 1023
# 2024-07-11 10:07:09.653377: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f783000 of size 1536 next 1024
# 2024-07-11 10:07:09.653394: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f783600 of size 1536 next 1025
# 2024-07-11 10:07:09.653412: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f783c00 of size 196608 next 1026
# 2024-07-11 10:07:09.653429: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f7b3c00 of size 196608 next 1027
# 2024-07-11 10:07:09.653446: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f7e3c00 of size 512 next 1028
# 2024-07-11 10:07:09.653463: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f7e3e00 of size 512 next 1029
# 2024-07-11 10:07:09.653480: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f7e4000 of size 512 next 1030
# 2024-07-11 10:07:09.653497: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f7e4200 of size 512 next 1031
# 2024-07-11 10:07:09.653514: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f7e4400 of size 147456 next 1032
# 2024-07-11 10:07:09.653531: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f808400 of size 147456 next 1033
# 2024-07-11 10:07:09.653549: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f82c400 of size 1792 next 1034
# 2024-07-11 10:07:09.653566: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f82cb00 of size 1792 next 1035
# 2024-07-11 10:07:09.653583: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f82d200 of size 1792 next 1036
# 2024-07-11 10:07:09.653600: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f82d900 of size 1792 next 1037
# 2024-07-11 10:07:09.653618: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f82e000 of size 212992 next 1038
# 2024-07-11 10:07:09.653635: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f862000 of size 212992 next 1039
# 2024-07-11 10:07:09.653652: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f896000 of size 512 next 1040
# 2024-07-11 10:07:09.653669: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f896200 of size 512 next 1041
# 2024-07-11 10:07:09.653686: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f896400 of size 512 next 1042
# 2024-07-11 10:07:09.653704: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f896600 of size 512 next 1043
# 2024-07-11 10:07:09.653721: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f896800 of size 147456 next 1044
# 2024-07-11 10:07:09.653738: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f8ba800 of size 147456 next 1045
# 2024-07-11 10:07:09.653755: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f8de800 of size 1792 next 1046
# 2024-07-11 10:07:09.653772: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f8def00 of size 1792 next 1047
# 2024-07-11 10:07:09.653789: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f8df600 of size 1792 next 1048
# 2024-07-11 10:07:09.653805: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f8dfd00 of size 1792 next 1049
# 2024-07-11 10:07:09.653823: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f8e0400 of size 229376 next 1050
# 2024-07-11 10:07:09.653840: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f918400 of size 229376 next 1051
# 2024-07-11 10:07:09.653857: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f950400 of size 512 next 1052
# 2024-07-11 10:07:09.653874: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f950600 of size 512 next 1053
# 2024-07-11 10:07:09.653891: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f950800 of size 512 next 1054
# 2024-07-11 10:07:09.653908: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f950a00 of size 512 next 1055
# 2024-07-11 10:07:09.653925: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f950c00 of size 147456 next 1056
# 2024-07-11 10:07:09.653942: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f974c00 of size 147456 next 1057
# 2024-07-11 10:07:09.653959: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f998c00 of size 2048 next 1058
# 2024-07-11 10:07:09.653976: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f999400 of size 2048 next 1059
# 2024-07-11 10:07:09.653993: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f999c00 of size 2048 next 1060
# 2024-07-11 10:07:09.654010: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f99a400 of size 2048 next 1061
# 2024-07-11 10:07:09.654027: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f99ac00 of size 245760 next 1062
# 2024-07-11 10:07:09.654044: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68f9d6c00 of size 245760 next 1063
# 2024-07-11 10:07:09.654062: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fa12c00 of size 512 next 1064
# 2024-07-11 10:07:09.654079: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fa12e00 of size 512 next 1065
# 2024-07-11 10:07:09.654095: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fa13000 of size 512 next 1066
# 2024-07-11 10:07:09.654112: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fa13200 of size 512 next 1067
# 2024-07-11 10:07:09.654129: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fa13400 of size 147456 next 1068
# 2024-07-11 10:07:09.654146: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fa37400 of size 147456 next 1069
# 2024-07-11 10:07:09.654163: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fa5b400 of size 2048 next 1070
# 2024-07-11 10:07:09.654180: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fa5bc00 of size 2048 next 1071
# 2024-07-11 10:07:09.654197: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fa5c400 of size 2048 next 1072
# 2024-07-11 10:07:09.654215: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fa5cc00 of size 2048 next 1073
# 2024-07-11 10:07:09.654232: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fa5d400 of size 262144 next 1074
# 2024-07-11 10:07:09.654250: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fa9d400 of size 262144 next 1075
# 2024-07-11 10:07:09.654267: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fadd400 of size 512 next 1076
# 2024-07-11 10:07:09.654290: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fadd600 of size 512 next 1077
# 2024-07-11 10:07:09.654307: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fadd800 of size 512 next 1078
# 2024-07-11 10:07:09.654324: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fadda00 of size 512 next 1079
# 2024-07-11 10:07:09.654341: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68faddc00 of size 147456 next 1080
# 2024-07-11 10:07:09.654358: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fb01c00 of size 147456 next 1081
# 2024-07-11 10:07:09.654375: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fb25c00 of size 2304 next 1082
# 2024-07-11 10:07:09.654393: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fb26500 of size 2304 next 1083
# 2024-07-11 10:07:09.654410: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fb26e00 of size 2304 next 1084
# 2024-07-11 10:07:09.654427: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fb27700 of size 2304 next 1085
# 2024-07-11 10:07:09.654444: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fb28000 of size 278528 next 1086
# 2024-07-11 10:07:09.654462: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fb6c000 of size 278528 next 1087
# 2024-07-11 10:07:09.654479: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fbb0000 of size 512 next 1088
# 2024-07-11 10:07:09.654496: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fbb0200 of size 512 next 1089
# 2024-07-11 10:07:09.654513: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fbb0400 of size 512 next 1090
# 2024-07-11 10:07:09.654529: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fbb0600 of size 512 next 1091
# 2024-07-11 10:07:09.654546: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fbb0800 of size 147456 next 1092
# 2024-07-11 10:07:09.654563: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fbd4800 of size 147456 next 1093
# 2024-07-11 10:07:09.654580: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fbf8800 of size 2304 next 1094
# 2024-07-11 10:07:09.654597: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fbf9100 of size 2304 next 1095
# 2024-07-11 10:07:09.654614: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fbf9a00 of size 2304 next 1096
# 2024-07-11 10:07:09.654631: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fbfa300 of size 2304 next 1097
# 2024-07-11 10:07:09.654649: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fbfac00 of size 294912 next 1098
# 2024-07-11 10:07:09.654666: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fc42c00 of size 294912 next 1099
# 2024-07-11 10:07:09.654683: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fc8ac00 of size 512 next 1100
# 2024-07-11 10:07:09.654700: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fc8ae00 of size 512 next 1101
# 2024-07-11 10:07:09.654717: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fc8b000 of size 512 next 1102
# 2024-07-11 10:07:09.654734: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fc8b200 of size 512 next 1103
# 2024-07-11 10:07:09.654751: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fc8b400 of size 147456 next 1104
# 2024-07-11 10:07:09.654768: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fcaf400 of size 147456 next 1105
# 2024-07-11 10:07:09.654785: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fcd3400 of size 2560 next 1106
# 2024-07-11 10:07:09.654803: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fcd3e00 of size 2560 next 1107
# 2024-07-11 10:07:09.654819: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fcd4800 of size 2560 next 1108
# 2024-07-11 10:07:09.654836: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fcd5200 of size 2560 next 1109
# 2024-07-11 10:07:09.654854: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fcd5c00 of size 311296 next 1110
# 2024-07-11 10:07:09.654871: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fd21c00 of size 311296 next 1111
# 2024-07-11 10:07:09.654889: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fd6dc00 of size 512 next 1112
# 2024-07-11 10:07:09.654906: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fd6de00 of size 512 next 1113
# 2024-07-11 10:07:09.654923: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fd6e000 of size 512 next 1114
# 2024-07-11 10:07:09.654939: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fd6e200 of size 512 next 1115
# 2024-07-11 10:07:09.654956: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fd6e400 of size 147456 next 1116
# 2024-07-11 10:07:09.654973: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fd92400 of size 147456 next 1117
# 2024-07-11 10:07:09.654991: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fdb6400 of size 5120 next 1118
# 2024-07-11 10:07:09.655008: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fdb7800 of size 5120 next 1119
# 2024-07-11 10:07:09.655025: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fdb8c00 of size 5120 next 1120
# 2024-07-11 10:07:09.655042: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc68fdba000 of size 5120 next 1121
# 2024-07-11 10:07:09.655069: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] Free  at 7fc68fdbb400 of size 2378752 next 18446744073709551615
# 2024-07-11 10:07:09.655086: I external/local_tsl/tsl/framework/bfc_allocator.cc:1080] Next region of size 33554432
# 2024-07-11 10:07:09.655104: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc690000000 of size 704512 next 553
# 2024-07-11 10:07:09.655121: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc6900ac000 of size 720896 next 573
# 2024-07-11 10:07:09.655138: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc69015c000 of size 147456 next 692
# 2024-07-11 10:07:09.655155: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc690180000 of size 147456 next 705
# 2024-07-11 10:07:09.655173: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc6901a4000 of size 15360 next 765
# 2024-07-11 10:07:09.655190: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc6901a7c00 of size 15360 next 766
# 2024-07-11 10:07:09.655207: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc6901ab800 of size 15360 next 768
# 2024-07-11 10:07:09.655224: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc6901af400 of size 15360 next 769
# 2024-07-11 10:07:09.655242: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc6901b3000 of size 12544 next 23
# 2024-07-11 10:07:09.655259: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc6901b6100 of size 32768 next 774
# 2024-07-11 10:07:09.655282: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc6901be100 of size 2048 next 784
# 2024-07-11 10:07:09.655300: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc6901be900 of size 2304 next 786
# 2024-07-11 10:07:09.655318: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc6901bf200 of size 2304 next 788
# 2024-07-11 10:07:09.655335: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc6901bfb00 of size 2560 next 789
# 2024-07-11 10:07:09.655352: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc6901c0500 of size 2560 next 792
# 2024-07-11 10:07:09.655369: I external/local_tsl/tsl/framework/bfc_allocator.cc:1100] InUse at 7fc6901c0f00 of size 2816 next 793
# ...
# 2024-07-11 10:07:09.687091: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 655360 totalling 1.25MiB
# 2024-07-11 10:07:09.687109: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 671744 totalling 1.28MiB
# 2024-07-11 10:07:09.687127: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 688128 totalling 1.31MiB
# 2024-07-11 10:07:09.687145: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 3 Chunks of size 704512 totalling 2.02MiB
# 2024-07-11 10:07:09.687163: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 720896 totalling 1.38MiB
# 2024-07-11 10:07:09.687181: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 737280 totalling 1.41MiB
# 2024-07-11 10:07:09.687198: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 753664 totalling 1.44MiB
# 2024-07-11 10:07:09.687216: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 770048 totalling 1.47MiB
# 2024-07-11 10:07:09.687234: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 786432 totalling 1.50MiB
# 2024-07-11 10:07:09.687252: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 802816 totalling 1.53MiB
# 2024-07-11 10:07:09.687270: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 819200 totalling 1.56MiB
# 2024-07-11 10:07:09.687293: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 835584 totalling 1.59MiB
# 2024-07-11 10:07:09.687311: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 851968 totalling 1.62MiB
# 2024-07-11 10:07:09.687329: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 868352 totalling 1.66MiB
# 2024-07-11 10:07:09.687346: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 3 Chunks of size 884736 totalling 2.53MiB
# 2024-07-11 10:07:09.687364: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 901120 totalling 1.72MiB
# 2024-07-11 10:07:09.687382: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 3 Chunks of size 917504 totalling 2.62MiB
# 2024-07-11 10:07:09.687400: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 3 Chunks of size 933888 totalling 2.67MiB
# 2024-07-11 10:07:09.687417: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 3 Chunks of size 950272 totalling 2.72MiB
# 2024-07-11 10:07:09.687435: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 3 Chunks of size 966656 totalling 2.77MiB
# 2024-07-11 10:07:09.687453: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 1 Chunks of size 3276800 totalling 3.12MiB
# 2024-07-11 10:07:09.687471: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 1 Chunks of size 5668864 totalling 5.41MiB
# 2024-07-11 10:07:09.687490: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 2 Chunks of size 15859712 totalling 30.25MiB
# 2024-07-11 10:07:09.687510: I external/local_tsl/tsl/framework/bfc_allocator.cc:1108] 1 Chunks of size 560398336 totalling 534.44MiB
# 2024-07-11 10:07:09.687529: I external/local_tsl/tsl/framework/bfc_allocator.cc:1112] Sum Total of in-use chunks: 658.17MiB
# 2024-07-11 10:07:09.687548: I external/local_tsl/tsl/framework/bfc_allocator.cc:1114] Total bytes in pool: 692518912 memory_limit_: 692518912 available bytes: 0 curr_region_allocation_bytes_: 2147483648
# 2024-07-11 10:07:09.687573: I external/local_tsl/tsl/framework/bfc_allocator.cc:1119] Stats:
# Limit:                       692518912
# InUse:                       690140160
# MaxInUse:                    690140160
# NumAllocs:                        8284
# MaxAllocSize:                560398336
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-07-11 10:07:09.687708: W external/local_tsl/tsl/framework/bfc_allocator.cc:499] ****************************************************************************xxxx********************
# 2024-07-11 10:07:09.698332: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 3276800 bytes.
# BufferAssignment OOM Debugging.
# BufferAssignment stats:
#              parameter allocation:  166.76MiB
#               constant allocation:         4B
#         maybe_live_out allocation:  165.65MiB
#      preallocated temp allocation:  498.41MiB
#   preallocated temp fragmentation:    8.13MiB (1.63%)
#                  total allocation:  665.19MiB
#               total fragmentation:    8.26MiB (1.24%)
# Peak buffers:
# 	Buffer 1:
# 		Size: 128.00MiB
# 		Operator: op_type="Conv2D" op_name="dense_net_1/dense_block_4_1/layer_16_1/conv2d_115_1/convolution" source_file="/data/hagemann/ml/venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1177
# 		XLA Label: custom-call
# 		Shape: u8[134217728]
# 		==========================
#
# 	Buffer 2:
# 		Size: 18.00MiB
# 		Operator: op_type="ReluGrad" op_name="gradient_tape/dense_net_1/transition_layer_1_1/re_lu_118_1/ReluGrad"
# 		XLA Label: fusion
# 		Shape: f32[64,512,12,12]
# 		==========================
#
# 	Buffer 3:
# 		Size: 15.12MiB
# 		Operator: op_name="XLA_Args"
# 		XLA Label: fusion
# 		Shape: f32[1408,2816,1,1]
# 		==========================
#
# 	Buffer 4:
# 		Size: 15.12MiB
# 		Operator: op_name="XLA_Retvals"
# 		XLA Label: fusion
# 		Shape: f32[1,1,2816,1408]
# 		==========================
#
# 	Buffer 5:
# 		Size: 15.12MiB
# 		Operator: op_name="XLA_Retvals"
# 		XLA Label: fusion
# 		Shape: f32[1,1,2816,1408]
# 		==========================
#
# 	Buffer 6:
# 		Size: 15.12MiB
# 		Operator: op_name="XLA_Retvals"
# 		XLA Label: fusion
# 		Shape: f32[1,1,2816,1408]
# 		==========================
#
# 	Buffer 7:
# 		Size: 11.25MiB
# 		Operator: op_type="ReluGrad" op_name="gradient_tape/dense_net_1/transition_layer_2_1/re_lu_119_1/ReluGrad"
# 		XLA Label: fusion
# 		Shape: f32[64,1280,6,6]
# 		==========================
#
# 	Buffer 8:
# 		Size: 9.00MiB
# 		Operator: op_type="Conv2D" op_name="dense_net_1/conv2d_1/convolution" source_file="/data/hagemann/ml/venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1177
# 		XLA Label: custom-call
# 		Shape: f32[64,64,24,24]
# 		==========================
#
# 	Buffer 9:
# 		Size: 7.88MiB
# 		Operator: op_type="ReluGrad" op_name="gradient_tape/dense_net_1/dense_block_1_1/layer_6_1/re_lu_11_1/ReluGrad"
# 		XLA Label: fusion
# 		Shape: f32[64,224,12,12]
# 		==========================
#
# 	Buffer 10:
# 		Size: 6.75MiB
# 		Operator: op_type="ReluGrad" op_name="gradient_tape/dense_net_1/dense_block_1_1/layer_5_1/re_lu_9_1/ReluGrad"
# 		XLA Label: fusion
# 		Shape: f32[64,192,12,12]
# 		==========================
#
# 	Buffer 11:
# 		Size: 6.19MiB
# 		Operator: op_type="ReluGrad" op_name="gradient_tape/dense_net_1/transition_layer_3_1/re_lu_120_1/ReluGrad"
# 		XLA Label: fusion
# 		Shape: f32[64,2816,3,3]
# 		==========================
#
# 	Buffer 12:
# 		Size: 5.62MiB
# 		Operator: op_type="Relu" op_name="dense_net_1/dense_block_1_1/layer_4_1/re_lu_7_1/Relu"
# 		XLA Label: fusion
# 		Shape: f32[64,160,12,12]
# 		==========================
#
# 	Buffer 13:
# 		Size: 5.34MiB
# 		Operator: op_type="Relu" op_name="dense_net_1/dense_block_2_1/layer_12_1/re_lu_35_1/Relu"
# 		XLA Label: fusion
# 		Shape: f32[64,608,6,6]
# 		==========================
#
# 	Buffer 14:
# 		Size: 5.06MiB
# 		Operator: op_type="Relu" op_name="dense_net_1/dense_block_2_1/layer_11_1/re_lu_33_1/Relu"
# 		XLA Label: fusion
# 		Shape: f32[64,576,6,6]
# 		==========================
#
# 	Buffer 15:
# 		Size: 4.78MiB
# 		Operator: op_type="Relu" op_name="dense_net_1/dense_block_2_1/layer_10_1/re_lu_31_1/Relu"
# 		XLA Label: fusion
# 		Shape: f32[64,544,6,6]
# 		==========================
#
#
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 history = model.fit(
#       2     train_ds,
#       3     class_weight=class_weights_dict,
#       4     epochs=10,
#       5     validation_data=test_ds,
#       6     callbacks=[reduce_lr, early_stopping],
#       7 )
#
# File /data/hagemann/ml/venv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /data/hagemann/ml/venv/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/home/hagemann/.local/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#
#   File "/home/hagemann/.local/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#
#   File "/home/hagemann/.local/lib/python3.12/asyncio/events.py", line 88, in _run
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#
#   File "/tmp/hagemann/ipykernel_54136/443205291.py", line 1, in <module>
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 318, in fit
#
#   File "/data/hagemann/ml/venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 121, in one_step_on_iterator
#
# Out of memory while trying to allocate 3276800 bytes.
# BufferAssignment OOM Debugging.
# BufferAssignment stats:
#              parameter allocation:  166.76MiB
#               constant allocation:         4B
#         maybe_live_out allocation:  165.65MiB
#      preallocated temp allocation:  498.41MiB
#   preallocated temp fragmentation:    8.13MiB (1.63%)
#                  total allocation:  665.19MiB
#               total fragmentation:    8.26MiB (1.24%)
# Peak buffers:
# 	Buffer 1:
# 		Size: 128.00MiB
# 		Operator: op_type="Conv2D" op_name="dense_net_1/dense_block_4_1/layer_16_1/conv2d_115_1/convolution" source_file="/data/hagemann/ml/venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1177
# 		XLA Label: custom-call
# 		Shape: u8[134217728]
# 		==========================
#
# 	Buffer 2:
# 		Size: 18.00MiB
# 		Operator: op_type="ReluGrad" op_name="gradient_tape/dense_net_1/transition_layer_1_1/re_lu_118_1/ReluGrad"
# 		XLA Label: fusion
# 		Shape: f32[64,512,12,12]
# 		==========================
#
# 	Buffer 3:
# 		Size: 15.12MiB
# 		Operator: op_name="XLA_Args"
# 		XLA Label: fusion
# 		Shape: f32[1408,2816,1,1]
# 		==========================
#
# 	Buffer 4:
# 		Size: 15.12MiB
# 		Operator: op_name="XLA_Retvals"
# 		XLA Label: fusion
# 		Shape: f32[1,1,2816,1408]
# 		==========================
#
# 	Buffer 5:
# 		Size: 15.12MiB
# 		Operator: op_name="XLA_Retvals"
# 		XLA Label: fusion
# 		Shape: f32[1,1,2816,1408]
# 		==========================
#
# 	Buffer 6:
# 		Size: 15.12MiB
# 		Operator: op_name="XLA_Retvals"
# 		XLA Label: fusion
# 		Shape: f32[1,1,2816,1408]
# 		==========================
#
# 	Buffer 7:
# 		Size: 11.25MiB
# 		Operator: op_type="ReluGrad" op_name="gradient_tape/dense_net_1/transition_layer_2_1/re_lu_119_1/ReluGrad"
# 		XLA Label: fusion
# 		Shape: f32[64,1280,6,6]
# 		==========================
#
# 	Buffer 8:
# 		Size: 9.00MiB
# 		Operator: op_type="Conv2D" op_name="dense_net_1/conv2d_1/convolution" source_file="/data/hagemann/ml/venv/lib/python3.12/site-packages/tensorflow/python/framework/ops.py" source_line=1177
# 		XLA Label: custom-call
# 		Shape: f32[64,64,24,24]
# 		==========================
#
# 	Buffer 9:
# 		Size: 7.88MiB
# 		Operator: op_type="ReluGrad" op_name="gradient_tape/dense_net_1/dense_block_1_1/layer_6_1/re_lu_11_1/ReluGrad"
# 		XLA Label: fusion
# 		Shape: f32[64,224,12,12]
# 		==========================
#
# 	Buffer 10:
# 		Size: 6.75MiB
# 		Operator: op_type="ReluGrad" op_name="gradient_tape/dense_net_1/dense_block_1_1/layer_5_1/re_lu_9_1/ReluGrad"
# 		XLA Label: fusion
# 		Shape: f32[64,192,12,12]
# 		==========================
#
# 	Buffer 11:
# 		Size: 6.19MiB
# 		Operator: op_type="ReluGrad" op_name="gradient_tape/dense_net_1/transition_layer_3_1/re_lu_120_1/ReluGrad"
# 		XLA Label: fusion
# 		Shape: f32[64,2816,3,3]
# 		==========================
#
# 	Buffer 12:
# 		Size: 5.62MiB
# 		Operator: op_type="Relu" op_name="dense_net_1/dense_block_1_1/layer_4_1/re_lu_7_1/Relu"
# 		XLA Label: fusion
# 		Shape: f32[64,160,12,12]
# 		==========================
#
# 	Buffer 13:
# 		Size: 5.34MiB
# 		Operator: op_type="Relu" op_name="dense_net_1/dense_block_2_1/layer_12_1/re_lu_35_1/Relu"
# 		XLA Label: fusion
# 		Shape: f32[64,608,6,6]
# 		==========================
#
# 	Buffer 14:
# 		Size: 5.06MiB
# 		Operator: op_type="Relu" op_name="dense_net_1/dense_block_2_1/layer_11_1/re_lu_33_1/Relu"
# 		XLA Label: fusion
# 		Shape: f32[64,576,6,6]
# 		==========================
#
# 	Buffer 15:
# 		Size: 4.78MiB
# 		Operator: op_type="Relu" op_name="dense_net_1/dense_block_2_1/layer_10_1/re_lu_31_1/Relu"
# 		XLA Label: fusion
# 		Shape: f32[64,544,6,6]
# 		==========================
#
#
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_one_step_on_iterator_80346]

# %%
from util import plot_history

# %%
plot_history(history)

# %%
# Load test data
x_test = []
y_test = []

for i, c in enumerate(classes):
    path = os.path.join(test_dir, c)
    for img_name in os.listdir(path):
        img = cv2.imread(os.path.join(path, img_name))
        if img is not None:  # Ensure the image was read correctly
            if greyscale:
                img = cv2.resize(img, (48, 48))
                # Image to greyscale and shape (48, 48, 1)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                img = np.expand_dims(img, axis=-1)  # Add channel dimension for greyscale images
            else:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            # Normalize the image
            img = img / 255.0
            x_test.append(img)
            y_test.append(i)

x_test = np.array(x_test)
y_test = np.array(y_test)

# Bruh, why you taking so long..

y_test_encoded = tf.keras.utils.to_categorical(y_test, num_classes=7)

# %%
# SAVE MODEL, if model is defined
if model is not None:
    model.save("emotion_recognition_model.h5")
    print("Model saved as emotion_recognition_model.h5")
else:
    # Load model
    model = tf.keras.models.load_model("emotion_recognition_model.h5")
    print("Model loaded from emotion_recognition_model.h5")

# Confusion matrix
from sklearn.metrics import confusion_matrix
import numpy as np
import seaborn as sns

# Evaluate model
evaluation = model.evaluate(x_test, y_test_encoded)

# print evaluation
print(evaluation)

# Predict test data
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)

from sklearn.metrics import classification_report

print("Classification Report:\n", classification_report(y_test, y_pred))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Normalize the confusion matrix
cm_normalized = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]

print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)

# Display normalized confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(
    cm_normalized,
    annot=True,
    fmt=".2f",
    xticklabels=classes,
    yticklabels=classes,
    cmap="Blues",
)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Normalized Confusion Matrix")
plt.show()

# 5x5 matrix with random pictures from the test set, labeled with the predicted emotion and the true emotion; text color is green if the prediction is correct, red otherwise
import random

plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    index = random.randint(0, len(x_test) - 1)
    img = x_test[index]
    img = np.reshape(img, [1, 48, 48, 1])
    prediction = model.predict(img)
    emotion = classes[np.argmax(prediction)]
    true_emotion = classes[y_test[index]]
    color = "g" if emotion == true_emotion else "r"
    # Image back to original size
    img = x_test[index]
    img = np.reshape(img, [48, 48])
    plt.imshow(img, cmap="gray")
    plt.title(f"Pred: {emotion}\nTrue: {true_emotion}", color=color)
    plt.axis("off")
    plt.tight_layout()

plt.show()

# %%
evaluation[0]

# %% [markdown]
# # Hyperparam Optimization

# %%
import numpy as np

def gaussian_peak(min_value, max_value, length, sharpness=0.01):
    offset = length // 2 + length // 5
    x = np.linspace(0, length - 1, length)
    peak_position = (max_value - min_value) / 2 + min_value
    peak = np.exp(-sharpness * ((x - offset) ** 2))
    scaled_peak = (peak - np.min(peak)) / (np.max(peak) - np.min(peak))
    scaled_peak = (max_value - min_value) * scaled_peak + min_value
    return np.round(scaled_peak).astype(int)

# Example usage:
min_value = 4
max_value = 32
length = 7

array_with_gaussian_peak = gaussian_peak(min_value, max_value, length)
print(array_with_gaussian_peak)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import optuna
import densenet
from tensorflow.keras import optimizers
import tensorflow as tf
import numpy as np
from util import evaluate

input_shape = (48, 48, 1)

def objective(trial):
    # Suggest the number of dense blocks
    num_blocks = trial.suggest_int('num_blocks', 2, 10)
    
    # Suggest the max and min layers per block
    min_layers = trial.suggest_int('min_layers', 4, 8)
    max_layers = trial.suggest_int('max_layers', 16, 32)
    num_layers_per_block = gaussian_peak(min_layers, max_layers, num_blocks)
    print("XXX", num_layers_per_block)
    # Suggest other parameters
    growth_rate = trial.suggest_categorical('growth_rate', [16, 32, 48])
    reduction = trial.suggest_uniform('reduction', 0.4, 0.6)
    dropout_rate = trial.suggest_uniform('dropout_rate', 0.0, 0.4)
    l2_regularization = trial.suggest_loguniform('l2_regularization', 1e-6, 1e-3)
    
    # Define the model using the suggested parameters
    args = dict(
        input_shape=input_shape,
        num_blocks=num_blocks,
        num_layers_per_block=num_layers_per_block,
        growth_rate=growth_rate,
        reduction=reduction,
        num_classes=7,  # Assuming the number of classes is fixed
        dropout_rate=dropout_rate,
        l2_regularization=l2_regularization
    )
    
    model = densenet.DenseNet(**args)
    model.build((None, *input_shape))
    model.compile(
        optimizer=optimizers.Adam(),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    history = model.fit(
        train_ds,
        class_weight=class_weights_dict,
        epochs=20,
        validation_data=test_ds,
        callbacks=[reduce_lr, early_stopping],
    )
    plot_history(history)
    evaluate(model, x_test, y_test, y_test_encoded, classes)
    loss, accuracy = model.evaluate(x_test, y_test_encoded)
    return loss

# %%
study = optuna.create_study(direction='minimize', study_name="custom-densenet", storage='sqlite:///optuna.db', load_if_exists=True)

# %%
study.optimize(objective, n_trials=50)

# %%
# Print the top 10 parameter sets
completed_trials = study.get_trials(deepcopy=False, states=[optuna.trial.TrialState.COMPLETE])

best_trials = sorted(completed_trials, key=lambda trial: trial.value)[:10]
for i, trial in enumerate(best_trials):
    print(f"Rank {i+1}: Loss = {trial.value}, Params = {trial.params}")

# %% [markdown]
# ## Setup

# %%
# Facial image emotion recognition using CNN
# Target classes: Angry, Disgusted, Fearful, Happy, Sad, Surprised, Neutral

import tensorflow as tf

NUM_THREADS = 32

tf.config.threading.set_intra_op_parallelism_threads(NUM_THREADS)
tf.config.threading.set_inter_op_parallelism_threads(NUM_THREADS)

# Switch to GPU
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
print(physical_devices)
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)


# DATASET
# files in dataset/test and dataset/train
# subfolders: angry, disgusted, fearful, happy, sad, surprised, neutral

# load dataset
train_dir = 'dataset_RAF_DB/train'
test_dir = 'dataset_RAF_DB/test'
# Out:
# 2024-07-08 13:46:16.579202: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-08 13:46:16.807798: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-08 13:46:17.442385: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Num GPUs Available:  1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-07-08 13:46:18.279987: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-08 13:46:18.403919: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-07-08 13:46:18.403953: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# Test data
# Check for the number of images in each class and the size of the images
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '0'  # 0 = alle Meldungen werden ausgegeben

# List of classes
classes = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

# Number of images in each class
print('Number of training images in each class:')
for c in classes:
    path = os.path.join(train_dir, c)
    print(f'{c}: {len(os.listdir(path))} images')
    
print('\nNumber of test images in each class:')
for c in classes:
    path = os.path.join(test_dir, c)
    print(f'{c}: {len(os.listdir(path))} images')
    
# Image size
img = cv2.imread('dataset/train/angry/Training_3908.jpg')
print(f'\nImage size: {img.shape}')

input_shape = img.shape

# Reduce image size to 48x48 pixels due to greyscale (original size: 48x48x3)
input_shape = (48, 48, 1)
# Out:
# Number of training images in each class:
# angry: 705 images
# disgust: 717 images
# fear: 281 images
# happy: 4772 images
# sad: 1982 images
# surprise: 1290 images
# neutral: 2524 images
#
# Number of test images in each class:
# angry: 162 images
# disgust: 160 images
# fear: 74 images
# happy: 1185 images
# sad: 478 images
# surprise: 329 images
# neutral: 680 images
#
# Image size: (48, 48, 3)

# %% [markdown]
# ## Preparing different models

# %%
# CNN MODEL
input_layer = tf.keras.layers.Input(shape=input_shape)

# Erster konventioneller Convolutional Pfad
conv1 = tf.keras.layers.Conv2D(16, (3, 3), padding='same')(input_layer)
conv1 = tf.keras.layers.BatchNormalization()(conv1)
conv1 = tf.keras.layers.ReLU()(conv1)
conv1 = tf.keras.layers.MaxPooling2D(2, 2)(conv1)
dropout1 = tf.keras.layers.Dropout(0.3)(conv1)

# Zweiter konventioneller Convolutional Pfad
conv2 = tf.keras.layers.Conv2D(32, (3, 3), padding='same')(dropout1)
conv2 = tf.keras.layers.BatchNormalization()(conv2)
conv2 = tf.keras.layers.ReLU()(conv2)
conv2 = tf.keras.layers.MaxPooling2D(2, 2)(conv2)
dropout2 = tf.keras.layers.Dropout(0.3)(conv2)

# Dritter konventioneller Convolutional Pfad
conv3 = tf.keras.layers.Conv2D(64, (3, 3), padding='same')(conv2)
conv3 = tf.keras.layers.BatchNormalization()(conv3)
conv3 = tf.keras.layers.LeakyReLU(negative_slope=0.01)(conv3)
conv3 = tf.keras.layers.MaxPooling2D(2, 2)(conv3)
dropout3 = tf.keras.layers.Dropout(0.3)(conv3)

# Vierter konventioneller Convolutional Pfad
conv4 = tf.keras.layers.Conv2D(128, (3, 3), padding='same')(dropout3)
conv4 = tf.keras.layers.BatchNormalization()(conv4)
conv4 = tf.keras.layers.LeakyReLU(negative_slope=0.01)(conv4)
conv4 = tf.keras.layers.MaxPooling2D(2, 2)(conv4)
dropout4 = tf.keras.layers.Dropout(0.3)(conv4)

# Paralleler Pfad mit Dilated Convolutions
# dilated1 = tf.keras.layers.Conv2D(32, (3, 3), padding='same', dilation_rate=3)(input_layer)
# dilated1 = tf.keras.layers.BatchNormalization()(dilated1)
# dilated1 = tf.keras.layers.LeakyReLU(negative_slope=0.001)(dilated1)
# dilated1 = tf.keras.layers.MaxPooling2D(2, 2)(dilated1)
# dropout1dilated = tf.keras.layers.Dropout(0.3)(dilated1)

# dilated2 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', dilation_rate=3)(dropout1dilated)
# dilated2 = tf.keras.layers.BatchNormalization()(dilated2)
# dilated2 = tf.keras.layers.LeakyReLU(negative_slope=0.001)(dilated2)
# dilated2 = tf.keras.layers.MaxPooling2D(2, 2)(dilated2)
# dropout2dilated = tf.keras.layers.Dropout(0.3)(dilated2)

# dilated3 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', dilation_rate=4)(dilated2)
# dilated3 = tf.keras.layers.BatchNormalization()(dilated3)
# dilated3 = tf.keras.layers.LeakyReLU(negative_slope=0.01)(dilated3)
# dilated3 = tf.keras.layers.MaxPooling2D(2, 2)(dilated3)

# Zusammenführung der Pfade
merged = tf.keras.layers.concatenate([dropout4])

# Flatten und Dense Layers
flat = tf.keras.layers.Flatten()(merged)
dense1 = tf.keras.layers.Dense(256)(flat)
dense1 = tf.keras.layers.BatchNormalization()(dense1)
dense1 = tf.keras.layers.ReLU()(dense1)
dropout = tf.keras.layers.Dropout(0.3)(dense1)
output = tf.keras.layers.Dense(7, activation='softmax')(dropout)

# Modell definieren
model = tf.keras.models.Model(inputs=input_layer, outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 48, 48, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 48, 48, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 48, 48, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_3 (ReLU)                  │ (None, 48, 48, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 24, 24, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 24, 24, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 24, 24, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 24, 24, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_4 (ReLU)                  │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 12, 12, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 12, 12, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 6, 6, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 6, 6, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ concatenate_1 (Concatenate)     │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_5 (ReLU)                  │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 396,103 (1.51 MB)
#  Trainable params: 395,111 (1.51 MB)
#  Non-trainable params: 992 (3.88 KB)

# %% [markdown]
# ## Loading the images from disk

# %%
greyscale = True
augmentation = False

# %%
def normalize_image(img):
    img = tf.cast(img, tf.float32) / 255.0  # normalize to [0,1] range
    return img

# Load the data
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='int',  # Integer-Labels
    image_size=(48, 48),
    batch_size=64,
    color_mode='grayscale' if greyscale else 'rgb',
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',  # Integer-Labels
    image_size=(48, 48),
    batch_size=64,
    color_mode='grayscale' if greyscale else 'rgb',
)

# Normalize the images to [0,1]
train_ds = train_ds.map(lambda img, label: (normalize_image(img), label))
test_ds = test_ds.map(lambda img, label: (normalize_image(img), label))
# Out:
# Found 12271 files belonging to 7 classes.
# Found 3068 files belonging to 7 classes.

# %%
def augment(img, label):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, max_delta=0.3)
    img = tf.image.random_contrast(img, lower=0.8, upper=1.2)
    return img, label

# One-Hot-Encoding of the labels
def one_hot_encode(image, label):
    label = tf.one_hot(label, depth=num_classes)
    return image, label

num_classes = 7

train_ds = train_ds.map(one_hot_encode)
test_ds = test_ds.map(one_hot_encode)

if augmentation:
    train_ds = train_ds.map(augment)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Show the first 16 images and their labels
for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    for i in range(16):
        ax = plt.subplot(4, 4, i + 1)
        if greyscale:
            plt.imshow(np.squeeze(images[i]), cmap='gray')
        else:
            plt.imshow(images[i])
        plt.title(np.argmax(labels[i]))
        plt.axis('off')
    plt.show()
# Out:
# 2024-07-08 13:47:16.820216: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Print one image (to confirm whether the images are represented as 48x48x1 tensors)
for img, label in train_ds.take(1):
    print(f"Image shape: {img.shape}, Label dtype: {label.dtype}")
    print(f"Image dtype: {img.dtype}, Label dtype: {label.dtype}")
    
    # Plot the image
    if greyscale:
        plt.imshow(np.squeeze(img[0]), cmap='gray')
    else:
        plt.imshow(img[0])
    plt.show()
# Out:
# Image shape: (64, 48, 48, 1), Label dtype: <dtype: 'float32'>
# Image dtype: <dtype: 'float32'>, Label dtype: <dtype: 'float32'>
# 2024-07-08 13:47:40.956208: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ## Class distribution and weights

# %%
import collections

def get_class_distribution(dataset):
    class_counts = collections.Counter()
    
    for _, label_batch in dataset:
        labels = tf.argmax(label_batch, axis=1)
        class_counts.update(labels.numpy())
    
    return class_counts

# Klassenverteilung im Trainingsdatensatz
train_class_distribution = get_class_distribution(train_ds)
print("Train Class Distribution:", train_class_distribution)

# Klassenverteilung im Testdatensatz
test_class_distribution = get_class_distribution(test_ds)
print("Test Class Distribution:", test_class_distribution)
# Out:
# 2024-07-08 13:47:47.468564: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Train Class Distribution: Counter({3: 4772, 4: 2524, 5: 1982, 6: 1290, 1: 717, 0: 705, 2: 281})
# Test Class Distribution: Counter({3: 1185, 4: 680, 5: 478, 6: 329, 0: 162, 1: 160, 2: 74})
# 2024-07-08 13:47:48.047926: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
import sklearn
from sklearn.utils import class_weight

# Load test data
x_train = []
y_train = []

for i, c in enumerate(classes):
    path = os.path.join(train_dir, c)
    for img_name in os.listdir(path):
        # img = cv2.imread(os.path.join(path, img_name))
        if img is not None:  # Ensure the image was read correctly
            # img = cv2.resize(img, (48, 48))
            # x_train.append(img)
            y_train.append(i)

# %%
y_train_encoded = tf.keras.utils.to_categorical(y_train, num_classes=7)

# Nehme an, y_train_labels sind die Labels deiner Trainingsdaten
y_train_labels = np.argmax(y_train_encoded, axis=1)
y_train_labels = y_train_labels.astype(np.int32)

# Berechnung der Klassengewichte
class_weights = class_weight.compute_class_weight(class_weight='balanced',
                                                  classes=np.unique(y_train_labels),
                                                  y=y_train_labels)

# Convert the class weights to a dictionary. Use np.int32 as the key type
class_weights_dict = {int(k): float(v) for k, v in zip(np.unique(y_train_labels), class_weights)}

print("Class weights:", class_weights_dict)
# Print the type of keys in the dictionary
print("Type of keys:", type(list(class_weights_dict.keys())[0]))
# Print the type of values in the dictionary
print("Type of values:", type(list(class_weights_dict.values())[0]))
# Out:
# Class weights: {0: 2.4865248226950354, 1: 2.4449093444909344, 2: 6.238434163701068, 3: 0.3673512154233026, 4: 0.884460141271443, 5: 1.3589147286821706, 6: 0.6945324881141046}
# Type of keys: <class 'int'>
# Type of values: <class 'float'>

# %%
# Callback functions
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=50, restore_best_weights=True, mode='max')
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=20, min_lr=0.00001, mode='max')

# %%
for image, label in train_ds.take(1):  # Only take the first batch
    print(label[0])  # Show the label
# Out:
# tf.Tensor([0. 0. 0. 1. 0. 0. 0.], shape=(7,), dtype=float32)
# 2024-07-08 13:49:04.482612: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ## Training & Evaluation

# %%
history = model.fit(
    train_ds,
    class_weight=class_weights_dict,
    epochs=5000,
    validation_data=test_ds,
    callbacks=[reduce_lr, early_stopping],
)
# Out:
# Epoch 1/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.1992 - loss: 2.3075 - val_accuracy: 0.3683 - val_loss: 1.7715 - learning_rate: 0.0010
# Epoch 2/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3022 - loss: 1.9030 - val_accuracy: 0.0746 - val_loss: 1.8745 - learning_rate: 0.0010
# Epoch 3/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3843 - loss: 1.7292 - val_accuracy: 0.5482 - val_loss: 1.3431 - learning_rate: 0.0010
# Epoch 4/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.4501 - loss: 1.5449 - val_accuracy: 0.5388 - val_loss: 1.3014 - learning_rate: 0.0010
# Epoch 5/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5020 - loss: 1.4184 - val_accuracy: 0.6040 - val_loss: 1.1094 - learning_rate: 0.0010
# Epoch 6/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5279 - loss: 1.3773 - val_accuracy: 0.6480 - val_loss: 1.0053 - learning_rate: 0.0010
# Epoch 7/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5475 - loss: 1.3079 - val_accuracy: 0.6248 - val_loss: 1.0458 - learning_rate: 0.0010
# Epoch 8/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5723 - loss: 1.2191 - val_accuracy: 0.6372 - val_loss: 1.0158 - learning_rate: 0.0010
# Epoch 9/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.5835 - loss: 1.1929 - val_accuracy: 0.6838 - val_loss: 0.8970 - learning_rate: 0.0010
# Epoch 10/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.5906 - loss: 1.1804 - val_accuracy: 0.6672 - val_loss: 0.9129 - learning_rate: 0.0010
# Epoch 11/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6081 - loss: 1.1298 - val_accuracy: 0.6496 - val_loss: 0.9594 - learning_rate: 0.0010
# Epoch 12/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6121 - loss: 1.1002 - val_accuracy: 0.6917 - val_loss: 0.8694 - learning_rate: 0.0010
# Epoch 13/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6294 - loss: 1.0701 - val_accuracy: 0.7057 - val_loss: 0.8323 - learning_rate: 0.0010
# Epoch 14/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6361 - loss: 1.0175 - val_accuracy: 0.6757 - val_loss: 0.9081 - learning_rate: 0.0010
# Epoch 15/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6408 - loss: 1.0029 - val_accuracy: 0.6382 - val_loss: 0.9923 - learning_rate: 0.0010
# Epoch 16/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6505 - loss: 1.0072 - val_accuracy: 0.7050 - val_loss: 0.8474 - learning_rate: 0.0010
# Epoch 17/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6521 - loss: 0.9618 - val_accuracy: 0.6868 - val_loss: 0.8800 - learning_rate: 0.0010
# Epoch 18/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6591 - loss: 0.9529 - val_accuracy: 0.6985 - val_loss: 0.8214 - learning_rate: 0.0010
# Epoch 19/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6807 - loss: 0.8937 - val_accuracy: 0.6809 - val_loss: 0.8690 - learning_rate: 0.0010
# Epoch 20/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.6715 - loss: 0.8788 - val_accuracy: 0.7158 - val_loss: 0.7895 - learning_rate: 0.0010
# Epoch 21/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6840 - loss: 0.8528 - val_accuracy: 0.7177 - val_loss: 0.8154 - learning_rate: 0.0010
# Epoch 22/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6804 - loss: 0.8469 - val_accuracy: 0.6900 - val_loss: 0.8560 - learning_rate: 0.0010
# Epoch 23/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6898 - loss: 0.8273 - val_accuracy: 0.7066 - val_loss: 0.8235 - learning_rate: 0.0010
# Epoch 24/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6972 - loss: 0.7874 - val_accuracy: 0.7213 - val_loss: 0.7747 - learning_rate: 0.0010
# Epoch 25/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7047 - loss: 0.8010 - val_accuracy: 0.7083 - val_loss: 0.8015 - learning_rate: 0.0010
# Epoch 26/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7055 - loss: 0.7768 - val_accuracy: 0.7158 - val_loss: 0.8157 - learning_rate: 0.0010
# Epoch 27/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7100 - loss: 0.7611 - val_accuracy: 0.7252 - val_loss: 0.7657 - learning_rate: 0.0010
# Epoch 28/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7190 - loss: 0.7545 - val_accuracy: 0.7210 - val_loss: 0.7893 - learning_rate: 0.0010
# Epoch 29/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7176 - loss: 0.7307 - val_accuracy: 0.7102 - val_loss: 0.8168 - learning_rate: 0.0010
# Epoch 30/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7252 - loss: 0.7076 - val_accuracy: 0.7145 - val_loss: 0.7817 - learning_rate: 0.0010
# Epoch 31/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7213 - loss: 0.7173 - val_accuracy: 0.7106 - val_loss: 0.8088 - learning_rate: 0.0010
# Epoch 32/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7217 - loss: 0.6999 - val_accuracy: 0.7233 - val_loss: 0.7675 - learning_rate: 0.0010
# Epoch 33/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7375 - loss: 0.6809 - val_accuracy: 0.7197 - val_loss: 0.7769 - learning_rate: 0.0010
# Epoch 34/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7284 - loss: 0.6725 - val_accuracy: 0.7334 - val_loss: 0.7489 - learning_rate: 0.0010
# Epoch 35/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7472 - loss: 0.6526 - val_accuracy: 0.7331 - val_loss: 0.7453 - learning_rate: 0.0010
# Epoch 36/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7497 - loss: 0.6562 - val_accuracy: 0.7021 - val_loss: 0.8374 - learning_rate: 0.0010
# Epoch 37/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7469 - loss: 0.6485 - val_accuracy: 0.7128 - val_loss: 0.8004 - learning_rate: 0.0010
# Epoch 38/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7454 - loss: 0.6324 - val_accuracy: 0.7174 - val_loss: 0.7887 - learning_rate: 0.0010
# Epoch 39/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7491 - loss: 0.6182 - val_accuracy: 0.6600 - val_loss: 0.9249 - learning_rate: 0.0010
# Epoch 40/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7502 - loss: 0.6347 - val_accuracy: 0.7269 - val_loss: 0.7969 - learning_rate: 0.0010
# Epoch 41/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7582 - loss: 0.6193 - val_accuracy: 0.7353 - val_loss: 0.7697 - learning_rate: 0.0010
# Epoch 42/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7563 - loss: 0.5743 - val_accuracy: 0.7484 - val_loss: 0.7478 - learning_rate: 0.0010
# Epoch 43/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7695 - loss: 0.5678 - val_accuracy: 0.7389 - val_loss: 0.7483 - learning_rate: 0.0010
# Epoch 44/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7619 - loss: 0.5854 - val_accuracy: 0.7275 - val_loss: 0.7779 - learning_rate: 0.0010
# Epoch 45/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7682 - loss: 0.5801 - val_accuracy: 0.7370 - val_loss: 0.7762 - learning_rate: 0.0010
# Epoch 46/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7722 - loss: 0.5520 - val_accuracy: 0.7432 - val_loss: 0.7719 - learning_rate: 0.0010
# Epoch 47/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7816 - loss: 0.5478 - val_accuracy: 0.7050 - val_loss: 0.8422 - learning_rate: 0.0010
# Epoch 48/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7754 - loss: 0.5539 - val_accuracy: 0.7419 - val_loss: 0.7696 - learning_rate: 0.0010
# Epoch 49/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7828 - loss: 0.5319 - val_accuracy: 0.7161 - val_loss: 0.7940 - learning_rate: 0.0010
# Epoch 50/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7817 - loss: 0.5168 - val_accuracy: 0.7194 - val_loss: 0.8139 - learning_rate: 0.0010
# Epoch 51/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7871 - loss: 0.5025 - val_accuracy: 0.7164 - val_loss: 0.7999 - learning_rate: 0.0010
# Epoch 52/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7851 - loss: 0.5225 - val_accuracy: 0.7445 - val_loss: 0.7610 - learning_rate: 0.0010
# Epoch 53/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7892 - loss: 0.5043 - val_accuracy: 0.7034 - val_loss: 0.8535 - learning_rate: 0.0010
# Epoch 54/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7813 - loss: 0.5122 - val_accuracy: 0.7060 - val_loss: 0.8427 - learning_rate: 0.0010
# Epoch 55/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7871 - loss: 0.5091 - val_accuracy: 0.7357 - val_loss: 0.7765 - learning_rate: 0.0010
# Epoch 56/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7874 - loss: 0.5017 - val_accuracy: 0.7363 - val_loss: 0.7961 - learning_rate: 0.0010
# Epoch 57/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7999 - loss: 0.4695 - val_accuracy: 0.6529 - val_loss: 0.9843 - learning_rate: 0.0010
# Epoch 58/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7969 - loss: 0.4910 - val_accuracy: 0.7337 - val_loss: 0.7805 - learning_rate: 0.0010
# Epoch 59/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7951 - loss: 0.4815 - val_accuracy: 0.7445 - val_loss: 0.7556 - learning_rate: 0.0010
# Epoch 60/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7967 - loss: 0.4939 - val_accuracy: 0.7435 - val_loss: 0.7609 - learning_rate: 0.0010
# Epoch 61/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7934 - loss: 0.4667 - val_accuracy: 0.7389 - val_loss: 0.7857 - learning_rate: 0.0010
# Epoch 62/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7999 - loss: 0.4695 - val_accuracy: 0.7366 - val_loss: 0.7984 - learning_rate: 0.0010
# Epoch 63/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8130 - loss: 0.4500 - val_accuracy: 0.7546 - val_loss: 0.7526 - learning_rate: 5.0000e-04
# Epoch 64/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8114 - loss: 0.4401 - val_accuracy: 0.7259 - val_loss: 0.7828 - learning_rate: 5.0000e-04
# Epoch 65/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8242 - loss: 0.4201 - val_accuracy: 0.7562 - val_loss: 0.7427 - learning_rate: 5.0000e-04
# Epoch 66/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8264 - loss: 0.4007 - val_accuracy: 0.7516 - val_loss: 0.7526 - learning_rate: 5.0000e-04
# Epoch 67/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8269 - loss: 0.4050 - val_accuracy: 0.7565 - val_loss: 0.7480 - learning_rate: 5.0000e-04
# Epoch 68/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8250 - loss: 0.3963 - val_accuracy: 0.7526 - val_loss: 0.7511 - learning_rate: 5.0000e-04
# Epoch 69/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8247 - loss: 0.4145 - val_accuracy: 0.7402 - val_loss: 0.7814 - learning_rate: 5.0000e-04
# Epoch 70/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8310 - loss: 0.3888 - val_accuracy: 0.7493 - val_loss: 0.7517 - learning_rate: 5.0000e-04
# Epoch 71/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8219 - loss: 0.4010 - val_accuracy: 0.7497 - val_loss: 0.7694 - learning_rate: 5.0000e-04
# Epoch 72/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8336 - loss: 0.3870 - val_accuracy: 0.7578 - val_loss: 0.7510 - learning_rate: 5.0000e-04
# Epoch 73/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8283 - loss: 0.3883 - val_accuracy: 0.7347 - val_loss: 0.8118 - learning_rate: 5.0000e-04
# Epoch 74/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8315 - loss: 0.3755 - val_accuracy: 0.7474 - val_loss: 0.7675 - learning_rate: 5.0000e-04
# Epoch 75/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8391 - loss: 0.3675 - val_accuracy: 0.7565 - val_loss: 0.7643 - learning_rate: 5.0000e-04
# Epoch 76/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8338 - loss: 0.3573 - val_accuracy: 0.7627 - val_loss: 0.7513 - learning_rate: 5.0000e-04
# Epoch 77/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8325 - loss: 0.3804 - val_accuracy: 0.7601 - val_loss: 0.7470 - learning_rate: 5.0000e-04
# Epoch 78/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8400 - loss: 0.3619 - val_accuracy: 0.7581 - val_loss: 0.7598 - learning_rate: 5.0000e-04
# Epoch 79/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8470 - loss: 0.3519 - val_accuracy: 0.7520 - val_loss: 0.7645 - learning_rate: 5.0000e-04
# Epoch 80/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8411 - loss: 0.3570 - val_accuracy: 0.7588 - val_loss: 0.7656 - learning_rate: 5.0000e-04
# Epoch 81/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8399 - loss: 0.3481 - val_accuracy: 0.7604 - val_loss: 0.7582 - learning_rate: 5.0000e-04
# Epoch 82/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8405 - loss: 0.3659 - val_accuracy: 0.7575 - val_loss: 0.7606 - learning_rate: 5.0000e-04
# Epoch 83/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8368 - loss: 0.3481 - val_accuracy: 0.7510 - val_loss: 0.7753 - learning_rate: 5.0000e-04
# Epoch 84/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8387 - loss: 0.3653 - val_accuracy: 0.7581 - val_loss: 0.7651 - learning_rate: 5.0000e-04
# Epoch 85/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8484 - loss: 0.3358 - val_accuracy: 0.7663 - val_loss: 0.7570 - learning_rate: 5.0000e-04
# Epoch 86/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8501 - loss: 0.3331 - val_accuracy: 0.7529 - val_loss: 0.7682 - learning_rate: 5.0000e-04
# Epoch 87/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8467 - loss: 0.3292 - val_accuracy: 0.7516 - val_loss: 0.7727 - learning_rate: 5.0000e-04
# Epoch 88/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8466 - loss: 0.3302 - val_accuracy: 0.7552 - val_loss: 0.7801 - learning_rate: 5.0000e-04
# Epoch 89/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8521 - loss: 0.3320 - val_accuracy: 0.7500 - val_loss: 0.7996 - learning_rate: 5.0000e-04
# Epoch 90/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8421 - loss: 0.3554 - val_accuracy: 0.7549 - val_loss: 0.7918 - learning_rate: 5.0000e-04
# Epoch 91/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8466 - loss: 0.3270 - val_accuracy: 0.7454 - val_loss: 0.7896 - learning_rate: 5.0000e-04
# Epoch 92/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8533 - loss: 0.3237 - val_accuracy: 0.7461 - val_loss: 0.7840 - learning_rate: 5.0000e-04
# Epoch 93/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8497 - loss: 0.3342 - val_accuracy: 0.7572 - val_loss: 0.7810 - learning_rate: 5.0000e-04
# Epoch 94/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8592 - loss: 0.3126 - val_accuracy: 0.7572 - val_loss: 0.7878 - learning_rate: 5.0000e-04
# Epoch 95/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8518 - loss: 0.3288 - val_accuracy: 0.7552 - val_loss: 0.7906 - learning_rate: 5.0000e-04
# Epoch 96/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8517 - loss: 0.3220 - val_accuracy: 0.7598 - val_loss: 0.7758 - learning_rate: 5.0000e-04
# Epoch 97/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8611 - loss: 0.3116 - val_accuracy: 0.7585 - val_loss: 0.8007 - learning_rate: 5.0000e-04
# Epoch 98/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8498 - loss: 0.3204 - val_accuracy: 0.7422 - val_loss: 0.8262 - learning_rate: 5.0000e-04
# Epoch 99/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8522 - loss: 0.3264 - val_accuracy: 0.7533 - val_loss: 0.8083 - learning_rate: 5.0000e-04
# Epoch 100/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8512 - loss: 0.3291 - val_accuracy: 0.7500 - val_loss: 0.8115 - learning_rate: 5.0000e-04
# Epoch 101/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8502 - loss: 0.3310 - val_accuracy: 0.7487 - val_loss: 0.8001 - learning_rate: 5.0000e-04
# Epoch 102/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8573 - loss: 0.3074 - val_accuracy: 0.7578 - val_loss: 0.7819 - learning_rate: 5.0000e-04
# Epoch 103/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8627 - loss: 0.3126 - val_accuracy: 0.7539 - val_loss: 0.8113 - learning_rate: 5.0000e-04
# Epoch 104/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8629 - loss: 0.3035 - val_accuracy: 0.7692 - val_loss: 0.7687 - learning_rate: 5.0000e-04
# Epoch 105/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8562 - loss: 0.3058 - val_accuracy: 0.7467 - val_loss: 0.8133 - learning_rate: 5.0000e-04
# Epoch 106/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8555 - loss: 0.3253 - val_accuracy: 0.7549 - val_loss: 0.7814 - learning_rate: 5.0000e-04
# Epoch 107/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8669 - loss: 0.2936 - val_accuracy: 0.7555 - val_loss: 0.7920 - learning_rate: 5.0000e-04
# Epoch 108/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8528 - loss: 0.3209 - val_accuracy: 0.7536 - val_loss: 0.8049 - learning_rate: 5.0000e-04
# Epoch 109/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8530 - loss: 0.3171 - val_accuracy: 0.7562 - val_loss: 0.7927 - learning_rate: 5.0000e-04
# Epoch 110/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8578 - loss: 0.3108 - val_accuracy: 0.7474 - val_loss: 0.8146 - learning_rate: 5.0000e-04
# Epoch 111/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8574 - loss: 0.3022 - val_accuracy: 0.7529 - val_loss: 0.8154 - learning_rate: 5.0000e-04
# Epoch 112/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8600 - loss: 0.3141 - val_accuracy: 0.7419 - val_loss: 0.8273 - learning_rate: 5.0000e-04
# Epoch 113/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8625 - loss: 0.2939 - val_accuracy: 0.7627 - val_loss: 0.8000 - learning_rate: 5.0000e-04
# Epoch 114/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8665 - loss: 0.2980 - val_accuracy: 0.7581 - val_loss: 0.8008 - learning_rate: 5.0000e-04
# Epoch 115/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8609 - loss: 0.2864 - val_accuracy: 0.7523 - val_loss: 0.8110 - learning_rate: 5.0000e-04
# Epoch 116/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8622 - loss: 0.3101 - val_accuracy: 0.7451 - val_loss: 0.8132 - learning_rate: 5.0000e-04
# Epoch 117/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8625 - loss: 0.3019 - val_accuracy: 0.7529 - val_loss: 0.8033 - learning_rate: 5.0000e-04
# Epoch 118/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8698 - loss: 0.2809 - val_accuracy: 0.7526 - val_loss: 0.8054 - learning_rate: 5.0000e-04
# Epoch 119/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8689 - loss: 0.2934 - val_accuracy: 0.7650 - val_loss: 0.7968 - learning_rate: 5.0000e-04
# Epoch 120/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8638 - loss: 0.2861 - val_accuracy: 0.7542 - val_loss: 0.8127 - learning_rate: 5.0000e-04
# Epoch 121/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8627 - loss: 0.3064 - val_accuracy: 0.7484 - val_loss: 0.8216 - learning_rate: 5.0000e-04
# Epoch 122/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8653 - loss: 0.3011 - val_accuracy: 0.7621 - val_loss: 0.7929 - learning_rate: 5.0000e-04
# Epoch 123/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8660 - loss: 0.2840 - val_accuracy: 0.7601 - val_loss: 0.7962 - learning_rate: 5.0000e-04
# Epoch 124/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8697 - loss: 0.2998 - val_accuracy: 0.7539 - val_loss: 0.7962 - learning_rate: 5.0000e-04
# Epoch 125/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8829 - loss: 0.2614 - val_accuracy: 0.7520 - val_loss: 0.7952 - learning_rate: 2.5000e-04
# Epoch 126/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8792 - loss: 0.2725 - val_accuracy: 0.7539 - val_loss: 0.8031 - learning_rate: 2.5000e-04
# Epoch 127/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8732 - loss: 0.2775 - val_accuracy: 0.7601 - val_loss: 0.7968 - learning_rate: 2.5000e-04
# Epoch 128/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8799 - loss: 0.2726 - val_accuracy: 0.7604 - val_loss: 0.7877 - learning_rate: 2.5000e-04
# Epoch 129/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8705 - loss: 0.2766 - val_accuracy: 0.7624 - val_loss: 0.7959 - learning_rate: 2.5000e-04
# Epoch 130/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8741 - loss: 0.2684 - val_accuracy: 0.7650 - val_loss: 0.7914 - learning_rate: 2.5000e-04
# Epoch 131/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8744 - loss: 0.2686 - val_accuracy: 0.7611 - val_loss: 0.7887 - learning_rate: 2.5000e-04
# Epoch 132/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8713 - loss: 0.2797 - val_accuracy: 0.7526 - val_loss: 0.8102 - learning_rate: 2.5000e-04
# Epoch 133/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8787 - loss: 0.2672 - val_accuracy: 0.7575 - val_loss: 0.7888 - learning_rate: 2.5000e-04
# Epoch 134/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8815 - loss: 0.2503 - val_accuracy: 0.7604 - val_loss: 0.7898 - learning_rate: 2.5000e-04
# Epoch 135/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8788 - loss: 0.2604 - val_accuracy: 0.7640 - val_loss: 0.7900 - learning_rate: 2.5000e-04
# Epoch 136/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8845 - loss: 0.2481 - val_accuracy: 0.7617 - val_loss: 0.7852 - learning_rate: 2.5000e-04
# Epoch 137/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8826 - loss: 0.2519 - val_accuracy: 0.7621 - val_loss: 0.7897 - learning_rate: 2.5000e-04
# Epoch 138/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8813 - loss: 0.2794 - val_accuracy: 0.7604 - val_loss: 0.7904 - learning_rate: 2.5000e-04
# Epoch 139/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8914 - loss: 0.2495 - val_accuracy: 0.7640 - val_loss: 0.7873 - learning_rate: 2.5000e-04
# Epoch 140/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8795 - loss: 0.2581 - val_accuracy: 0.7647 - val_loss: 0.7962 - learning_rate: 2.5000e-04
# Epoch 141/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8815 - loss: 0.2601 - val_accuracy: 0.7660 - val_loss: 0.7967 - learning_rate: 2.5000e-04
# Epoch 142/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8785 - loss: 0.2568 - val_accuracy: 0.7650 - val_loss: 0.7813 - learning_rate: 2.5000e-04
# Epoch 143/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8898 - loss: 0.2528 - val_accuracy: 0.7604 - val_loss: 0.7962 - learning_rate: 2.5000e-04
# Epoch 144/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8847 - loss: 0.2527 - val_accuracy: 0.7575 - val_loss: 0.8060 - learning_rate: 2.5000e-04
# Epoch 145/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8824 - loss: 0.2478 - val_accuracy: 0.7673 - val_loss: 0.7902 - learning_rate: 1.2500e-04
# Epoch 146/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8872 - loss: 0.2365 - val_accuracy: 0.7689 - val_loss: 0.7847 - learning_rate: 1.2500e-04
# Epoch 147/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8881 - loss: 0.2362 - val_accuracy: 0.7676 - val_loss: 0.7869 - learning_rate: 1.2500e-04
# Epoch 148/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8858 - loss: 0.2481 - val_accuracy: 0.7679 - val_loss: 0.7872 - learning_rate: 1.2500e-04
# Epoch 149/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8929 - loss: 0.2249 - val_accuracy: 0.7666 - val_loss: 0.7869 - learning_rate: 1.2500e-04
# Epoch 150/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8899 - loss: 0.2302 - val_accuracy: 0.7679 - val_loss: 0.7858 - learning_rate: 1.2500e-04
# Epoch 151/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8869 - loss: 0.2409 - val_accuracy: 0.7718 - val_loss: 0.7877 - learning_rate: 1.2500e-04
# Epoch 152/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8953 - loss: 0.2301 - val_accuracy: 0.7705 - val_loss: 0.7912 - learning_rate: 1.2500e-04
# Epoch 153/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8919 - loss: 0.2329 - val_accuracy: 0.7699 - val_loss: 0.7963 - learning_rate: 1.2500e-04
# Epoch 154/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8899 - loss: 0.2360 - val_accuracy: 0.7722 - val_loss: 0.7963 - learning_rate: 1.2500e-04
# Epoch 155/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8900 - loss: 0.2369 - val_accuracy: 0.7673 - val_loss: 0.8115 - learning_rate: 1.2500e-04
# Epoch 156/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8908 - loss: 0.2313 - val_accuracy: 0.7608 - val_loss: 0.8120 - learning_rate: 1.2500e-04
# Epoch 157/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8935 - loss: 0.2233 - val_accuracy: 0.7683 - val_loss: 0.7878 - learning_rate: 1.2500e-04
# Epoch 158/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8947 - loss: 0.2356 - val_accuracy: 0.7696 - val_loss: 0.7966 - learning_rate: 1.2500e-04
# Epoch 159/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8921 - loss: 0.2396 - val_accuracy: 0.7663 - val_loss: 0.7963 - learning_rate: 1.2500e-04
# Epoch 160/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8900 - loss: 0.2207 - val_accuracy: 0.7656 - val_loss: 0.7955 - learning_rate: 1.2500e-04
# Epoch 161/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8855 - loss: 0.2393 - val_accuracy: 0.7679 - val_loss: 0.7952 - learning_rate: 1.2500e-04
# Epoch 162/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8931 - loss: 0.2245 - val_accuracy: 0.7673 - val_loss: 0.7933 - learning_rate: 1.2500e-04
# Epoch 163/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8891 - loss: 0.2427 - val_accuracy: 0.7699 - val_loss: 0.7989 - learning_rate: 1.2500e-04
# Epoch 164/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8849 - loss: 0.2546 - val_accuracy: 0.7692 - val_loss: 0.7962 - learning_rate: 1.2500e-04
# Epoch 165/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8894 - loss: 0.2311 - val_accuracy: 0.7679 - val_loss: 0.7976 - learning_rate: 1.2500e-04
# Epoch 166/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8914 - loss: 0.2273 - val_accuracy: 0.7666 - val_loss: 0.8119 - learning_rate: 1.2500e-04
# Epoch 167/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8994 - loss: 0.2192 - val_accuracy: 0.7679 - val_loss: 0.7984 - learning_rate: 1.2500e-04
# Epoch 168/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8983 - loss: 0.2213 - val_accuracy: 0.7712 - val_loss: 0.7954 - learning_rate: 1.2500e-04
# Epoch 169/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8854 - loss: 0.2412 - val_accuracy: 0.7689 - val_loss: 0.7973 - learning_rate: 1.2500e-04
# Epoch 170/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8953 - loss: 0.2233 - val_accuracy: 0.7692 - val_loss: 0.7995 - learning_rate: 1.2500e-04
# Epoch 171/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8937 - loss: 0.2201 - val_accuracy: 0.7712 - val_loss: 0.8050 - learning_rate: 1.2500e-04
# Epoch 172/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8879 - loss: 0.2249 - val_accuracy: 0.7666 - val_loss: 0.8078 - learning_rate: 1.2500e-04
# Epoch 173/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9006 - loss: 0.2172 - val_accuracy: 0.7705 - val_loss: 0.8008 - learning_rate: 1.2500e-04
# Epoch 174/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8871 - loss: 0.2344 - val_accuracy: 0.7559 - val_loss: 0.8194 - learning_rate: 1.2500e-04
# Epoch 175/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8944 - loss: 0.2243 - val_accuracy: 0.7653 - val_loss: 0.7954 - learning_rate: 6.2500e-05
# Epoch 176/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8964 - loss: 0.2235 - val_accuracy: 0.7624 - val_loss: 0.8104 - learning_rate: 6.2500e-05
# Epoch 177/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8944 - loss: 0.2293 - val_accuracy: 0.7725 - val_loss: 0.7953 - learning_rate: 6.2500e-05
# Epoch 178/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8946 - loss: 0.2159 - val_accuracy: 0.7699 - val_loss: 0.7993 - learning_rate: 6.2500e-05
# Epoch 179/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8987 - loss: 0.2333 - val_accuracy: 0.7669 - val_loss: 0.7966 - learning_rate: 6.2500e-05
# Epoch 180/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9022 - loss: 0.2278 - val_accuracy: 0.7666 - val_loss: 0.7977 - learning_rate: 6.2500e-05
# Epoch 181/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8941 - loss: 0.2265 - val_accuracy: 0.7669 - val_loss: 0.7968 - learning_rate: 6.2500e-05
# Epoch 182/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8932 - loss: 0.2161 - val_accuracy: 0.7696 - val_loss: 0.7958 - learning_rate: 6.2500e-05
# Epoch 183/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8987 - loss: 0.2115 - val_accuracy: 0.7702 - val_loss: 0.7992 - learning_rate: 6.2500e-05
# Epoch 184/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9008 - loss: 0.2059 - val_accuracy: 0.7669 - val_loss: 0.7964 - learning_rate: 6.2500e-05
# Epoch 185/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8945 - loss: 0.2186 - val_accuracy: 0.7705 - val_loss: 0.7980 - learning_rate: 6.2500e-05
# Epoch 186/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8967 - loss: 0.2195 - val_accuracy: 0.7660 - val_loss: 0.8010 - learning_rate: 6.2500e-05
# Epoch 187/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8974 - loss: 0.2224 - val_accuracy: 0.7709 - val_loss: 0.7995 - learning_rate: 6.2500e-05
# Epoch 188/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8963 - loss: 0.2205 - val_accuracy: 0.7679 - val_loss: 0.7952 - learning_rate: 6.2500e-05
# Epoch 189/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.8966 - loss: 0.2294 - val_accuracy: 0.7679 - val_loss: 0.8010 - learning_rate: 6.2500e-05
# Epoch 190/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8994 - loss: 0.2116 - val_accuracy: 0.7699 - val_loss: 0.8022 - learning_rate: 6.2500e-05
# Epoch 191/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9053 - loss: 0.2248 - val_accuracy: 0.7728 - val_loss: 0.7971 - learning_rate: 6.2500e-05
# Epoch 192/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8981 - loss: 0.2252 - val_accuracy: 0.7709 - val_loss: 0.7989 - learning_rate: 6.2500e-05
# Epoch 193/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9008 - loss: 0.2040 - val_accuracy: 0.7689 - val_loss: 0.7998 - learning_rate: 6.2500e-05
# Epoch 194/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9040 - loss: 0.2080 - val_accuracy: 0.7702 - val_loss: 0.8009 - learning_rate: 6.2500e-05
# Epoch 195/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8989 - loss: 0.2153 - val_accuracy: 0.7709 - val_loss: 0.7990 - learning_rate: 6.2500e-05
# Epoch 196/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8983 - loss: 0.2194 - val_accuracy: 0.7663 - val_loss: 0.8071 - learning_rate: 6.2500e-05
# Epoch 197/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8983 - loss: 0.2113 - val_accuracy: 0.7676 - val_loss: 0.8018 - learning_rate: 6.2500e-05
# Epoch 198/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8994 - loss: 0.2159 - val_accuracy: 0.7709 - val_loss: 0.7983 - learning_rate: 6.2500e-05
# Epoch 199/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8998 - loss: 0.2133 - val_accuracy: 0.7686 - val_loss: 0.8020 - learning_rate: 6.2500e-05
# Epoch 200/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9005 - loss: 0.2214 - val_accuracy: 0.7754 - val_loss: 0.8026 - learning_rate: 6.2500e-05
# Epoch 201/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9053 - loss: 0.2100 - val_accuracy: 0.7640 - val_loss: 0.8089 - learning_rate: 6.2500e-05
# Epoch 202/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9005 - loss: 0.2067 - val_accuracy: 0.7640 - val_loss: 0.8133 - learning_rate: 6.2500e-05
# Epoch 203/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8976 - loss: 0.2153 - val_accuracy: 0.7696 - val_loss: 0.8017 - learning_rate: 6.2500e-05
# Epoch 204/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9013 - loss: 0.2146 - val_accuracy: 0.7686 - val_loss: 0.8017 - learning_rate: 6.2500e-05
# Epoch 205/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9022 - loss: 0.2083 - val_accuracy: 0.7679 - val_loss: 0.8025 - learning_rate: 6.2500e-05
# Epoch 206/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9000 - loss: 0.1965 - val_accuracy: 0.7699 - val_loss: 0.8006 - learning_rate: 6.2500e-05
# Epoch 207/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8930 - loss: 0.2215 - val_accuracy: 0.7650 - val_loss: 0.8123 - learning_rate: 6.2500e-05
# Epoch 208/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9034 - loss: 0.2125 - val_accuracy: 0.7702 - val_loss: 0.8021 - learning_rate: 6.2500e-05
# Epoch 209/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8998 - loss: 0.2133 - val_accuracy: 0.7673 - val_loss: 0.8087 - learning_rate: 6.2500e-05
# Epoch 210/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9017 - loss: 0.2083 - val_accuracy: 0.7673 - val_loss: 0.8084 - learning_rate: 6.2500e-05
# Epoch 211/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9060 - loss: 0.1978 - val_accuracy: 0.7686 - val_loss: 0.8045 - learning_rate: 6.2500e-05
# Epoch 212/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8958 - loss: 0.2190 - val_accuracy: 0.7666 - val_loss: 0.8076 - learning_rate: 6.2500e-05
# Epoch 213/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9039 - loss: 0.1937 - val_accuracy: 0.7663 - val_loss: 0.8027 - learning_rate: 6.2500e-05
# Epoch 214/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8997 - loss: 0.2236 - val_accuracy: 0.7650 - val_loss: 0.8113 - learning_rate: 6.2500e-05
# Epoch 215/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9009 - loss: 0.2076 - val_accuracy: 0.7683 - val_loss: 0.8031 - learning_rate: 6.2500e-05
# Epoch 216/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9016 - loss: 0.2082 - val_accuracy: 0.7683 - val_loss: 0.8039 - learning_rate: 6.2500e-05
# Epoch 217/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9043 - loss: 0.2021 - val_accuracy: 0.7699 - val_loss: 0.8033 - learning_rate: 6.2500e-05
# Epoch 218/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9031 - loss: 0.2082 - val_accuracy: 0.7689 - val_loss: 0.8011 - learning_rate: 6.2500e-05
# Epoch 219/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9013 - loss: 0.2073 - val_accuracy: 0.7650 - val_loss: 0.8060 - learning_rate: 6.2500e-05
# Epoch 220/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9031 - loss: 0.2157 - val_accuracy: 0.7647 - val_loss: 0.8155 - learning_rate: 6.2500e-05
# Epoch 221/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9053 - loss: 0.1939 - val_accuracy: 0.7666 - val_loss: 0.8075 - learning_rate: 3.1250e-05
# Epoch 222/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9025 - loss: 0.2126 - val_accuracy: 0.7650 - val_loss: 0.8047 - learning_rate: 3.1250e-05
# Epoch 223/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9028 - loss: 0.1979 - val_accuracy: 0.7650 - val_loss: 0.8043 - learning_rate: 3.1250e-05
# Epoch 224/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9043 - loss: 0.2042 - val_accuracy: 0.7669 - val_loss: 0.8048 - learning_rate: 3.1250e-05
# Epoch 225/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9072 - loss: 0.1931 - val_accuracy: 0.7692 - val_loss: 0.8023 - learning_rate: 3.1250e-05
# Epoch 226/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8987 - loss: 0.2176 - val_accuracy: 0.7676 - val_loss: 0.8037 - learning_rate: 3.1250e-05
# Epoch 227/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9008 - loss: 0.2141 - val_accuracy: 0.7699 - val_loss: 0.8015 - learning_rate: 3.1250e-05
# Epoch 228/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9026 - loss: 0.1973 - val_accuracy: 0.7683 - val_loss: 0.8046 - learning_rate: 3.1250e-05
# Epoch 229/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9012 - loss: 0.2107 - val_accuracy: 0.7656 - val_loss: 0.8034 - learning_rate: 3.1250e-05
# Epoch 230/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9002 - loss: 0.2061 - val_accuracy: 0.7669 - val_loss: 0.8047 - learning_rate: 3.1250e-05
# Epoch 231/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9046 - loss: 0.2049 - val_accuracy: 0.7663 - val_loss: 0.8041 - learning_rate: 3.1250e-05
# Epoch 232/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8974 - loss: 0.2044 - val_accuracy: 0.7660 - val_loss: 0.8097 - learning_rate: 3.1250e-05
# Epoch 233/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9028 - loss: 0.1983 - val_accuracy: 0.7683 - val_loss: 0.8076 - learning_rate: 3.1250e-05
# Epoch 234/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9029 - loss: 0.2096 - val_accuracy: 0.7679 - val_loss: 0.8027 - learning_rate: 3.1250e-05
# Epoch 235/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8949 - loss: 0.2196 - val_accuracy: 0.7676 - val_loss: 0.8049 - learning_rate: 3.1250e-05
# Epoch 236/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9053 - loss: 0.1957 - val_accuracy: 0.7630 - val_loss: 0.8053 - learning_rate: 3.1250e-05
# Epoch 237/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9059 - loss: 0.1956 - val_accuracy: 0.7718 - val_loss: 0.8039 - learning_rate: 3.1250e-05
# Epoch 238/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9069 - loss: 0.2005 - val_accuracy: 0.7692 - val_loss: 0.8029 - learning_rate: 3.1250e-05
# Epoch 239/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9026 - loss: 0.2037 - val_accuracy: 0.7663 - val_loss: 0.8018 - learning_rate: 3.1250e-05
# Epoch 240/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9069 - loss: 0.1983 - val_accuracy: 0.7650 - val_loss: 0.8058 - learning_rate: 3.1250e-05
# Epoch 241/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9109 - loss: 0.1965 - val_accuracy: 0.7669 - val_loss: 0.8037 - learning_rate: 1.5625e-05
# Epoch 242/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9092 - loss: 0.2087 - val_accuracy: 0.7656 - val_loss: 0.8033 - learning_rate: 1.5625e-05
# Epoch 243/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9017 - loss: 0.2074 - val_accuracy: 0.7686 - val_loss: 0.8048 - learning_rate: 1.5625e-05
# Epoch 244/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9004 - loss: 0.2114 - val_accuracy: 0.7673 - val_loss: 0.8060 - learning_rate: 1.5625e-05
# Epoch 245/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9080 - loss: 0.2065 - val_accuracy: 0.7666 - val_loss: 0.8055 - learning_rate: 1.5625e-05
# Epoch 246/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9068 - loss: 0.1990 - val_accuracy: 0.7653 - val_loss: 0.8064 - learning_rate: 1.5625e-05
# Epoch 247/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9025 - loss: 0.2126 - val_accuracy: 0.7650 - val_loss: 0.8079 - learning_rate: 1.5625e-05
# Epoch 248/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8984 - loss: 0.2086 - val_accuracy: 0.7660 - val_loss: 0.8039 - learning_rate: 1.5625e-05
# Epoch 249/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9002 - loss: 0.2001 - val_accuracy: 0.7663 - val_loss: 0.8047 - learning_rate: 1.5625e-05
# Epoch 250/5000
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8953 - loss: 0.2145 - val_accuracy: 0.7656 - val_loss: 0.8034 - learning_rate: 1.5625e-05

# %%
# Plot training history (loss and accuracy)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Load test data
x_test = []
y_test = []

for i, c in enumerate(classes):
    path = os.path.join(test_dir, c)
    for img_name in os.listdir(path):
        img = cv2.imread(os.path.join(path, img_name))
        if img is not None:  # Ensure the image was read correctly
            if greyscale:
                img = cv2.resize(img, (48, 48))
                # Image to greyscale and shape (48, 48, 1)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                img = np.expand_dims(img, axis=-1)  # Add channel dimension for greyscale images
            # Normalize the image
            img = img / 255.0
            x_test.append(img)
            y_test.append(i)

x_test = np.array(x_test)
y_test = np.array(y_test)

# Bruh, why you taking so long..

y_test_encoded = tf.keras.utils.to_categorical(y_test, num_classes=7)

# Print one image as matrix
print(x_test[0].shape)
print(type(x_test))
print(x_test[0])
# Out:
# (48, 48, 1)
# <class 'numpy.ndarray'>
# [[[0.30588235]
#   [0.21960784]
#   [0.21176471]
#   ...
#   [0.67843137]
#   [0.55294118]
#   [0.48627451]]
#
#  [[0.24705882]
#   [0.20784314]
#   [0.32156863]
#   ...
#   [0.71764706]
#   [0.57254902]
#   [0.53333333]]
#
#  [[0.23921569]
#   [0.25490196]
#   [0.30588235]
#   ...
#   [0.65882353]
#   [0.49411765]
#   [0.47058824]]
#
#  ...
#
#  [[0.24705882]
#   [0.24705882]
#   [0.23921569]
#   ...
#   [0.8627451 ]
#   [0.8627451 ]
#   [0.85490196]]
#
#  [[0.23921569]
#   [0.2627451 ]
#   [0.24313725]
#   ...
#   [0.85882353]
#   [0.86666667]
#   [0.87058824]]
#
#  [[0.26666667]
#   [0.25882353]
#   [0.25098039]
#   ...
#   [0.85098039]
#   [0.87843137]
#   [0.88627451]]]

# %%
# As a test, print one image from the training set
print(train_ds.take(1))
for img, label in train_ds.take(1):
    print(img[0])
    print(label[0])
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 48, 48, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None, 7), dtype=tf.float32, name=None))>
# tf.Tensor(
# [[[0.04985703]
#   [0.05473856]
#   [0.08143382]
#   ...
#   [0.1089664 ]
#   [0.18239379]
#   [0.18587285]]
#
#  [[0.06995507]
#   [0.09001225]
#   [0.06493056]
#   ...
#   [0.09413816]
#   [0.10238971]
#   [0.15596394]]
#
#  [[0.08613834]
#   [0.0637255 ]
#   [0.04610566]
#   ...
#   [0.06841641]
#   [0.12779818]
#   [0.11589052]]
#
#  ...
#
#  [[0.36846405]
#   [0.376634  ]
#   [0.37254903]
#   ...
#   [0.5955882 ]
#   [0.59487337]
#   [0.6040849 ]]
#
#  [[0.3640523 ]
#   [0.36078432]
#   [0.37984067]
#   ...
#   [0.6232639 ]
#   [0.62009805]
#   [0.6346405 ]]
#
#  [[0.37499315]
#   [0.36962825]
#   [0.37405366]
#   ...
#   [0.6312976 ]
#   [0.6321895 ]
#   [0.6457584 ]]], shape=(48, 48, 1), dtype=float32)
# tf.Tensor([0. 0. 0. 0. 1. 0. 0.], shape=(7,), dtype=float32)
# 2024-07-08 14:33:07.621119: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# if history is not None:

#     # PLOT TRAINING AND VALIDATION ACCURACY
#     plt.plot(history.history['accuracy'], label='accuracy')
#     plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
#     plt.xlabel('Epoch')
#     plt.ylabel('Accuracy')
#     plt.legend(loc='lower right')
#     plt.show()

#     # PLOT TRAINING AND VALIDATION LOSS
#     plt.plot(history.history['loss'], label='loss')
#     plt.plot(history.history['val_loss'], label = 'val_loss')
#     plt.xlabel('Epoch')
#     plt.ylabel('Loss')
#     plt.legend(loc='upper right')
#     plt.show()
    
#     # Zugreifen auf die Metriken im Trainingsverlauf
#     accuracy = history.history['accuracy']
#     val_accuracy = history.history['val_accuracy']

#     # Beispielausgabe der Genauigkeit
#     print("Training Accuracy:", accuracy)
#     print("Validation Accuracy:", val_accuracy)


# SAVE MODEL, if model is defined

if model is not None: 
    model.save('emotion_recognition_model.h5')
    print('Model saved as emotion_recognition_model.h5')
else:
    # Load model
    model = tf.keras.models.load_model('emotion_recognition_model.h5')
    print('Model loaded from emotion_recognition_model.h5')

# Confusion matrix
from sklearn.metrics import confusion_matrix
import numpy as np
import seaborn as sns

# Evaluate model
evaluation = model.evaluate(x_test, y_test_encoded)

# print evaluation
print(evaluation)

# Predict test data
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)

from sklearn.metrics import classification_report
print('Classification Report:\n', classification_report(y_test, y_pred))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

print("Confusion Matrix:\n", cm)
print("Normalized Confusion Matrix:\n", cm_normalized)

# Display normalized confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', xticklabels=classes, yticklabels=classes, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Normalized Confusion Matrix')
plt.show()

# TEST MODEL
# Load test image
file_path = 'dataset_RAF_DB/test/angry/test_0037_aligned.jpg'
img = x_test[0]

# Display image (back to original size)
img = np.reshape(img, [48, 48])
plt.imshow(img, cmap='gray')
plt.axis('off')
plt.show()

img = x_test[0]
img = np.reshape(img, [1, 48, 48, 1])
# Predict emotion
prediction = model.predict(img)
emotion = classes[np.argmax(prediction)]
print(f'Predicted emotion: {emotion}')

# Display prediction
plt.bar(classes, prediction[0])
plt.ylabel('Probability')
plt.show()

# 5x5 matrix with random pictures from the test set, labeled with the predicted emotion and the true emotion; text color is green if the prediction is correct, red otherwise
import random

plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    index = random.randint(0, len(x_test) - 1)
    img = x_test[index]
    img = np.reshape(img, [1, 48, 48, 1])
    prediction = model.predict(img)
    emotion = classes[np.argmax(prediction)]
    true_emotion = classes[y_test[index]]
    color = 'g' if emotion == true_emotion else 'r'
    # Image back to original size
    img = x_test[index]
    img = np.reshape(img, [48, 48])
    plt.imshow(img, cmap='gray')
    plt.title(f'Pred: {emotion}\nTrue: {true_emotion}', color=color)
    plt.axis('off')
    plt.tight_layout()
    
plt.show()
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as emotion_recognition_model.h5
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6658 - loss: 2.0665
# [4.184970855712891, 0.45208606123924255]
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.69      0.67       162
#            1       0.45      0.53      0.48       160
#            2       0.61      0.58      0.60        74
#            3       0.91      0.89      0.90      1185
#            4       0.08      0.12      0.10       478
#            5       0.02      0.04      0.03       329
#            6       0.09      0.04      0.05       680
#
#     accuracy                           0.45      3068
#    macro avg       0.40      0.41      0.40      3068
# weighted avg       0.46      0.45      0.45      3068
#
# Confusion Matrix:
#  [[ 111    9    7   16    9    8    2]
#  [  16   85    1   13   29   15    1]
#  [   4    6   43    6    4    5    6]
#  [  10   19    4 1051   60   28   13]
#  [   9   21    2   37   59  346    4]
#  [  10   13   11    9   36   12  238]
#  [   8   38    2   29  506   71   26]]
# Normalized Confusion Matrix:
#  [[0.68518519 0.05555556 0.04320988 0.09876543 0.05555556 0.04938272
#   0.01234568]
#  [0.1        0.53125    0.00625    0.08125    0.18125    0.09375
#   0.00625   ]
#  [0.05405405 0.08108108 0.58108108 0.08108108 0.05405405 0.06756757
#   0.08108108]
#  [0.00843882 0.01603376 0.00337553 0.88691983 0.05063291 0.02362869
#   0.01097046]
#  [0.01882845 0.04393305 0.0041841  0.07740586 0.12343096 0.72384937
#   0.0083682 ]
#  [0.03039514 0.03951368 0.03343465 0.02735562 0.10942249 0.03647416
#   0.72340426]
#  [0.01176471 0.05588235 0.00294118 0.04264706 0.74411765 0.10441176
#   0.03823529]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Predicted emotion: angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
